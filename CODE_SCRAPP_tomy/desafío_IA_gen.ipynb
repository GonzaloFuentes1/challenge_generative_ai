# %% [markdown]
# # First trys

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt # Para visualización básica

# --- 1. Consulta a Wikidata ---
endpoint_url = "https://query.wikidata.org/sparql"

# Ejemplo: Propiedades directas del Tango (Q9799)
query = """
SELECT ?propUrl ?propLabel ?valueUrl ?valueLabel WHERE {
  wd:Q208239 ?propUrl ?valueUrl .
  # ?propInstance wikibase:directClaim ?propUrl . # Obtener la propiedad directa
  # ?propInstance rdfs:label ?propLabel .
  # ?valueUrl rdfs:label ?valueLabel .
  FILTER(LANG(?propLabel) = "es" || LANG(?propLabel) = "en")
  FILTER(LANG(?valueLabel) = "es" || LANG(?valueLabel) = "en")
} LIMIT 50
"""

def get_sparql_results(endpoint, query):
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

results = get_sparql_results(endpoint_url, query)

# --- 2. Procesar Datos y Construir Grafo ---
triplets = []
for result in results["results"]["bindings"]:
    prop_label = result.get('propLabel', {}).get('value')
    value_label = result.get('valueLabel', {}).get('value')
    # Simple filtro para asegurar que tenemos datos
    if prop_label and value_label:
        triplets.append({"Entidad": "Tango", "Relacion": prop_label, "Valor": value_label})

df_triplets = pd.DataFrame(triplets)
# Limpieza adicional podría ser necesaria aquí (eliminar duplicados, etc.)
print(df_triplets.head())

G = nx.DiGraph()
entity_node = "Salsa"
G.add_node(entity_node) # Nodo central

for index, row in df_triplets.iterrows():
    value_node = row['Valor']
    relation_label = row['Relacion']
    G.add_node(value_node)
    G.add_edge(entity_node, value_node, label=relation_label) # Añadir arista con etiqueta

print(f"Grafo creado con {G.number_of_nodes()} nodos y {G.number_of_edges()} aristas.")

# --- 3. Almacenar y Visualizar (Ejemplo Básico) ---

# Almacenar (ejemplo como lista de aristas)
# nx.write_edgelist(G, "tango_kg.csv", delimiter=",", data=['label'])
# print("Grafo guardado como tango_kg.csv")

# Visualizar (muy básico, puede ser caótico para grafos grandes)
plt.figure(figsize=(9, 12))
pos = nx.spring_layout(G, k=0.9) # Algoritmo de posicionamiento
nx.draw(G, pos, with_labels=True, node_size=500, node_color="skyblue", font_size=8, edge_color="gray")
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)
plt.title("Grafo de Conocimiento Básico para Salsa")
plt.show()

# (Alternativa de visualización más interactiva abajo)
# Out:
#   Entidad      Relacion            Valor
# 0   Tango   instance of      music genre
# 1   Tango  instancia de      music genre
# 2   Tango   instance of   género musical
# 3   Tango  instancia de   género musical
# 4   Tango   subclass of  música tropical
# Grafo creado con 16 nodos y 15 aristas.

# %%
# Ejemplo con pyvis (instalar con: pip install pyvis)
from pyvis.network import Network

net = Network(notebook=True, directed=True, cdn_resources='remote') # 'remote' usa JS de internet, 'inline' lo incrusta
net.from_nx(G) # Cargar desde el grafo networkx

# Extraer etiquetas de las aristas para mostrarlas
edge_data = zip(G.edges(data=True), G.edges())
for e, edge_key in edge_data:
    # e es una tupla (nodo_origen, nodo_destino, datos_arista)
    src = e[0]
    dst = e[1]
    data = e[2]
    if 'label' in data:
        edge_info = net.get_edge(edge_key) # pyvis puede asignar ID diferente
        if edge_info: # Asegurarse que la arista existe en pyvis
             net.get_edge(edge_info['id'])['title'] = data['label'] # Mostrar etiqueta al pasar el mouse

net.show_buttons(filter_=['physics']) # Añadir controles
net.show("tango_kg_interactive.html")
print("Grafo interactivo guardado como tango_kg_interactive.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 15
#      13 data = e[2]
#      14 if 'label' in data:
# ---> 15     edge_info = net.get_edge(edge_key) # pyvis puede asignar ID diferente
#      16     if edge_info: # Asegurarse que la arista existe en pyvis
#      17          net.get_edge(edge_info['id'])['title'] = data['label'] # Mostrar etiqueta al pasar el mouse
#
# AttributeError: 'Network' object has no attribute 'get_edge'

# %%
import time
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
# ... (resto de tu código de importación y la función find_wikidata_qid)

endpoint_url = "https://query.wikidata.org/sparql"

def find_wikidata_qid(entity_label, entity_type_qid=None, lang="es"):
    # ... (código de la función como antes) ...
    try:
        results = sparql.query().convert()
    except Exception as e: # Captura genérica para simplificar, idealmente más específica
        print(f"Error al consultar Wikidata para '{entity_label}': {e}")
        return [] # Devuelve lista vacía en caso de error
    # ... (resto del procesamiento de resultados) ...
    return qids

# --- Lista de entidades a buscar ---
entidades_a_buscar = [
    {"label": "Salsa", "type_qid": "Q188451"},
    {"label": "Mercedes Sosa", "type_qid": "Q177220"}, # Asumiendo Q177220 es cantante
    {"label": "Buenos Aires", "type_qid": "Q5119"},
    {"label": "Tango", "type_qid": "Q188451"}, # Añadido Tango
    # ... añade más entidades aquí ...
]

all_results = {}
for entidad in entidades_a_buscar:
    print(f"Buscando QID para: {entidad['label']} (Tipo: {entidad.get('type_qid', 'N/A')})...")
    qids_encontrados = find_wikidata_qid(entidad['label'], entidad.get('type_qid'))
    all_results[entidad['label']] = qids_encontrados
    print(pd.DataFrame(qids_encontrados))
    print("-" * 30)
    # --- PAUSA AÑADIDA ---
    print("Esperando 1 segundo antes de la siguiente consulta...")
    time.sleep(1) # Espera 1 segundo. Ajusta este valor si sigues recibiendo 429.

# Ahora all_results contiene los QIDs encontrados para cada entidad
# Puedes proceder a usar estos QIDs para construir los grafos
# Out:
# Buscando QID para: Salsa (Tipo: Q188451)...
# Error al consultar Wikidata para 'Salsa': name 'sparql' is not defined
# Empty DataFrame
# Columns: []
# Index: []
# ------------------------------
# Esperando 1 segundo antes de la siguiente consulta...
# Buscando QID para: Mercedes Sosa (Tipo: Q177220)...
# Error al consultar Wikidata para 'Mercedes Sosa': name 'sparql' is not defined
# Empty DataFrame
# Columns: []
# Index: []
# ------------------------------
# Esperando 1 segundo antes de la siguiente consulta...
# Buscando QID para: Buenos Aires (Tipo: Q5119)...
# Error al consultar Wikidata para 'Buenos Aires': name 'sparql' is not defined
# Empty DataFrame
# Columns: []
# Index: []
# ------------------------------
# Esperando 1 segundo antes de la siguiente consulta...
# Buscando QID para: Tango (Tipo: Q188451)...
# Error al consultar Wikidata para 'Tango': name 'sparql' is not defined
# Empty DataFrame
# Columns: []
# Index: []
# ------------------------------
# Esperando 1 segundo antes de la siguiente consulta...

# %% [markdown]
# # Veamos ahora para automatizar y sacar más identidades

# %%
# -*- coding: utf-8 -*-
"""
Wikidata Cultural KG Builder
Autor: Tú (hola, Tomniko!)
Requisitos: pip install SPARQLWrapper pandas networkx matplotlib
"""

from SPARQLWrapper import SPARQLWrapper, JSON
import json
import time
from typing import Dict, List, Tuple, Optional
import networkx as nx
import matplotlib.pyplot as plt

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "en,es"  # orden de preferencia para etiquetas

# ----------------------------
# Utilidades SPARQL / Wikidata
# ----------------------------

def _sparql(query: str, *, endpoint: str = WIKIDATA_ENDPOINT, throttle_s: float = 0.75) -> dict:
    """Ejecuta una consulta SPARQL y devuelve el JSON ya convertido."""
    s = SPARQLWrapper(endpoint)
    s.setQuery(query)
    s.setReturnFormat(JSON)
    res = s.query().convert()
    # throttle ligero para ser buen ciudadano con el endpoint
    if throttle_s > 0:
        time.sleep(throttle_s)
    return res

def _values_block(var: str, qids: List[str]) -> str:
    """Genera un bloque VALUES para SPARQL, p.ej. VALUES ?x { wd:Q298 wd:Q30 }"""
    qids_norm = [qid if qid.startswith("Q") else qid for qid in qids]
    wd_terms = " ".join(f"wd:{q}" for q in qids_norm)
    return f"VALUES {var} {{ {wd_terms} }}"

def _property_path(prop_qid: str) -> str:
    """
    Devuelve el identificador 'wdt:Pxxx' a partir del QID de la propiedad Pxxx.
    Puedes pasar ya 'P27' y devolverá 'wdt:P27'.
    """
    p = prop_qid if prop_qid.startswith("P") else prop_qid
    return f"wdt:{p}"

def _label_service() -> str:
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# ---------------------------------------------
# 1) Búsqueda de entidades por filtros (genérico)
# ---------------------------------------------

def search_entities_by_filters(
    country_qids: List[str],
    filters: Dict[str, List[str]],
    limit: int = 200,
    offset: int = 0
) -> List[Tuple[str, str]]:
    """
    Busca entidades que cumplan:
      - (al menos uno) de los países en country_qids (típicamente P27: país de ciudadanía,
        pero esto se pasa en 'filters' para flexibilidad),
      - y además TODOS los filtros dados (cada filtro es PROP_Pxxx -> [QIDs]).
    Retorna lista de (item_qid, item_label).
    NOTA: Este método es flexible: incluye el país como un filtro más (ej: {'P27': ['Q298']}).
    """
    # combinamos país dentro de filters si no vino ya
    filters = dict(filters)  # copia
    if "P27" not in filters and country_qids:
        filters["P27"] = country_qids

    # Construimos cláusulas VALUES por cada propiedad
    values_blocks = []
    where_blocks = []
    i = 0
    for p, vals in filters.items():
        i += 1
        var_obj = f"?v{i}"
        values_blocks.append(_values_block(var_obj, vals))
        where_blocks.append(f"?item {_property_path(p)} {var_obj} .")

    query = f"""
    SELECT DISTINCT ?item ?itemLabel WHERE {{
      {' '.join(values_blocks)}
      {' '.join(where_blocks)}
      {_label_service()}
    }}
    LIMIT {limit}
    OFFSET {offset}
    """.strip()

    data = _sparql(query)
    out = []
    for b in data["results"]["bindings"]:
        qid = b["item"]["value"].split("/")[-1]
        label = b.get("itemLabel", {}).get("value", qid)
        out.append((qid, label))
    return out

def paginate_search(
    country_qids: List[str],
    filters: Dict[str, List[str]],
    max_entities: int = 300
) -> List[Tuple[str, str]]:
    """Pagina la búsqueda para traer hasta max_entities."""
    all_items = []
    batch = 200
    offset = 0
    while len(all_items) < max_entities:
        rows = search_entities_by_filters(country_qids, filters, limit=min(batch, max_entities - len(all_items)), offset=offset)
        if not rows:
            break
        all_items.extend(rows)
        offset += len(rows)
    return all_items

# ----------------------------------------------------------------
# 2) Extraer tripletas interesantes para una lista de entidades Q
# ----------------------------------------------------------------

DEFAULT_PROP_WHITELIST = [
    "P31",   # instancia de
    "P106",  # ocupación
    "P136",  # género (musical/estilo)
    "P495",  # país de origen
    "P27",   # país de ciudadanía
    "P19",   # lugar de nacimiento
    "P20",   # lugar de fallecimiento
    "P69",   # educado en
    "P166",  # premio recibido
    "P737",  # influenciado por
    "P739",  # influencia en
    "P135",  # movimiento
    "P1303", # instrumento
    "P264",  # discográfica
    "P451",  # pareja
    "P800",  # obra destacada
    "P279",  # subclase de
    "P361",  # parte de
    "P131",  # ubicado en la entidad territorial administrativa
]

def fetch_triplets_for_entities(
    item_qids: List[str],
    prop_whitelist: Optional[List[str]] = None
) -> List[dict]:
    """
    Devuelve tripletas ⟨entidad, relacion, valor⟩ con metadatos:
      {
        "subject_qid": "Qxxxx", "subject_label": "...",
        "property_pid": "P106", "property_label": "ocupación",
        "object_id": "Qyyyy" o literal, "object_label": "...", "object_is_entity": bool
      }
    """
    if not item_qids:
        return []

    prop_whitelist = prop_whitelist or DEFAULT_PROP_WHITELIST
    # Construimos filtro de propiedades
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = _values_block("?item", item_qids)

    # Nota: usamos wdt: (propiedad directa) para simplificar
    query = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      {values_items}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """.strip()

    data = _sparql(query)
    triplets = []
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel", {}).get("value", s_qid)
        p_iri = b["p"]["value"]
        prop_pid = p_iri.split("/")[-1]  # wdt:Pxxx
        prop_pid = prop_pid.split(":")[-1] if ":" in prop_pid else prop_pid
        prop_label = b.get("propLabel", {}).get("value", prop_pid)

        o_val = b["o"]["value"]
        o_label = b.get("oLabel", {}).get("value", o_val)
        # ¿el objeto es entidad Q... o literal?
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]
            is_ent = True
        else:
            o_id = o_val  # literal tal cual
            is_ent = False

        triplets.append({
            "subject_qid": s_qid,
            "subject_label": s_label,
            "property_pid": prop_pid,
            "property_label": prop_label,
            "object_id": o_id,
            "object_label": o_label,
            "object_is_entity": is_ent
        })
    return triplets

# ---------------------------------------------
# 3) Construcción de un diccionario de grafo KG
# ---------------------------------------------

def build_graph_dict(
    triplets: List[dict],
    metadata: Optional[dict] = None
) -> dict:
    """
    Crea un dict JSON con nodos/edges (solo entidades como nodos; los literales van a nodos 'L:...').
    """
    nodes = {}
    edges = []

    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {
                "id": node_id,
                "label": label,
                "type": "entity" if is_entity else "literal"
            }

    for t in triplets:
        subj_id = t["subject_qid"]
        subj_label = t["subject_label"]
        add_node(subj_id, subj_label, True)

        if t["object_is_entity"]:
            obj_id = t["object_id"]
            obj_label = t["object_label"]
            add_node(obj_id, obj_label, True)
        else:
            # colapsamos literales como nodos con prefijo L:
            obj_id = f"L:{t['object_id']}"
            obj_label = t["object_label"]
            add_node(obj_id, obj_label, False)

        edges.append({
            "source": subj_id,
            "target": obj_id,
            "property_pid": t["property_pid"],
            "property_label": t["property_label"]
        })

    return {
        "metadata": metadata or {},
        "nodes": list(nodes.values()),
        "edges": edges
    }

def save_graph_json(graph_dict: dict, path: str):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(graph_dict, f, ensure_ascii=False, indent=2)

def load_graph_json(path: str) -> dict:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

# ----------------------------
# 4) Visualización desde JSON
# ----------------------------

def plot_graph_from_json(
    path: str,
    max_nodes: int = 300,
    label_edges: bool = True,
    k_layout: float = 0.7,
    figsize: Tuple[int, int] = (10, 10)
):
    """
    Carga un .json del KG y lo grafica en una figura de matplotlib (no guarda PNG).
    """
    data = load_graph_json(path)
    G = nx.DiGraph()

    # limitar para plots grandes
    nodes = data["nodes"][:max_nodes]
    node_ids = set(n["id"] for n in nodes)
    id2label = {n["id"]: n["label"] for n in nodes}

    for n in nodes:
        G.add_node(n["id"], label=n["label"], ntype=n["type"])

    for e in data["edges"]:
        if e["source"] in node_ids and e["target"] in node_ids:
            G.add_edge(e["source"], e["target"], label=e["property_label"])

    plt.figure(figsize=figsize)
    pos = nx.spring_layout(G, k=k_layout, seed=42)
    nx.draw(
        G, pos,
        with_labels=True,
        labels=id2label,
        node_size=500,
        node_color="skyblue",
        font_size=8,
        edge_color="gray",
        arrows=True
    )
    if label_edges:
        edge_labels = nx.get_edge_attributes(G, 'label')
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)
    plt.title(data.get("metadata", {}).get("title", "Grafo de Conocimiento"))
    plt.tight_layout()
    plt.show()

# ----------------------------
# 5) Ejemplos de uso
# ----------------------------
if __name__ == "__main__":
    # EJEMPLO A: Pintores de Chile
    # - País de ciudadanía: Chile (Q298) -> propiedad P27
    # - Ocupación: pintor (Q1028181) -> propiedad P106
    #chile = ["Q298"]
    #pintor = ["Q1028181"]
    #items_chile_pintores = paginate_search(
    #    country_qids=chile,
    #    filters={"P27": chile, "P106": pintor},   # puedes sumar más filtros si quieres
    #    max_entities=120
    #)
    #print(f"Encontradas {len(items_chile_pintores)} entidades (pintores de Chile).")
#
    #triplets_chile = fetch_triplets_for_entities([qid for qid, _ in items_chile_pintores])
    #graph_chile = build_graph_dict(
    #    triplets_chile,
    #    metadata={"title": "Pintores de Chile (subgrafo)", "filters": {"P27": chile, "P106": pintor}}
    #)
    #save_graph_json(graph_chile, "GC_pintores_chile.json")
    #print("Guardado: GC_pintores_chile.json")
#
    ## Para graficar cuando quieras:
    #plot_graph_from_json("GC_pintores_chile.json", max_nodes=250)

    # EJEMPLO B: Cultura urbana de Colombia (reggaetón/género + cantautor/rapero, etc.)
    # Ajusta QIDs a tu definición de “cultura urbana”:
    #   Colombia: Q739 (país de ciudadanía) P27
    #   Reggaetón (género): Q218493 -> P136
    #   (opcional) Rapero: Q203509 -> P106
    #   (opcional) Cantautor / compositor: (busca el QID exacto que quieras usar)
    colombia = ["Q739"]
    reggaeton = ["Q218493"]
    singer_songwriter = ["Q488205"]
    # Si quieres añadir raperos:
    # raperos = ["Q203509"]
    items_urb_col = paginate_search(
        country_qids=colombia,
        filters={
            "P27": colombia,
            "P106": singer_songwriter,
            # "P106": raperos,  # descomenta y ajusta si quieres combinar
        },
        max_entities=150
    )
    print(f"Encontradas {len(items_urb_col)} entidades (cultura urbana Colombia).")

    triplets_col = fetch_triplets_for_entities([qid for qid, _ in items_urb_col])
    graph_col = build_graph_dict(
        triplets_col,
        metadata={"title": "Cantantes de Colombia (subgrafo)", "filters": {"P27": colombia, "P106": singer_songwriter}}
    )
    save_graph_json(graph_col, "GC_cantantes_de_colombia.json")
    print("Guardado: GC_cantantes_de_colombia.json")

    # Para graficar cuando quieras:
    plot_graph_from_json("GC_cantantes_de_colombia.json", max_nodes=15)
# Out:
# Encontradas 60 entidades (cultura urbana Colombia).
# Guardado: GC_cantantes_de_colombia.json
# C:\Users\tomas\AppData\Local\Temp\ipykernel_45880\2087420331.py:309: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
if __name__ == "__main__":
    # EJEMPLO A: Pintores de Chile
    # - País de ciudadanía: Chile (Q298) -> propiedad P27
    # - Ocupación: pintor (Q1028181) -> propiedad P106
    chile = ["Q298"]
    pintor = ["Q1028181"]
    items_chile_pintores = paginate_search(
        country_qids=chile,
        filters={"P27": chile, "P106": pintor},   # puedes sumar más filtros si quieres
        max_entities=120
    )
    print(f"Encontradas {len(items_chile_pintores)} entidades (pintores de Chile).")
    triplets_chile = fetch_triplets_for_entities([qid for qid, _ in items_chile_pintores])
    graph_chile = build_graph_dict(
        triplets_chile,
        metadata={"title": "Pintores de Chile (subgrafo)", "filters": {"P27": chile, "P106": pintor}}
    )
    save_graph_json(graph_chile, "GC_pintores_chile.json")
    print("Guardado: GC_pintores_chile.json")
#
    ## Para graficar cuando quieras:
    plot_graph_from_json("GC_pintores_chile.json", max_nodes=100)
# Out:
# Encontradas 120 entidades (pintores de Chile).
# Guardado: GC_pintores_chile.json
# C:\Users\tomas\AppData\Local\Temp\ipykernel_45880\2087420331.py:309: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Scrapping de pintores en LATAM

# %%
if __name__ == "__main__":
    # Países LATAM → QIDs (Wikidata)
    LATAM_COUNTRIES_QIDS = {
        "Argentina": "Q414",
        "Bolivia": "Q750",
        "Brasil": "Q155",
        "Chile": "Q298",
        "Colombia": "Q739",
        "Costa Rica": "Q800",
        "Cuba": "Q241",
        "Ecuador": "Q736",
        "El Salvador": "Q792",
        "Guatemala": "Q774",
        "Honduras": "Q783",
        "México": "Q96",
        "Nicaragua": "Q811",
        "Panamá": "Q804",
        "Paraguay": "Q733",
        "Perú": "Q419",
        "República Dominicana": "Q786",
        "Uruguay": "Q77",
        "Venezuela": "Q717",
    }

    # Lista de QIDs para el filtro por ciudadanía (P27)
    latam_country_qids = list(LATAM_COUNTRIES_QIDS.values())

    # QID de ocupación: pintor
    pintor_qid = "Q1028181"  # occupation (P106) = painter

    # 🔎 Búsqueda de “pintores de LATAM” (usa las funciones que ya te dejé)
    items_latam_pintores = paginate_search(
        country_qids=latam_country_qids,
        filters={
            "P27": latam_country_qids,     # país de ciudadanía ∈ LATAM
            "P106": [pintor_qid],          # ocupación = pintor
        },
        max_entities=10000
    )

    #  Tripletas + JSON
    triplets = fetch_triplets_for_entities([qid for qid, _ in items_latam_pintores])
    graph_latam = build_graph_dict(
        triplets,
        metadata={
            "title": "Pintores Latinoamericanos (subgrafo)",
            "filters": {"P27": latam_country_qids, "P106": [pintor_qid]}
        }
    )
    save_graph_json(graph_latam, "kg_pintores_latam.json")

    # Cuando quieras graficar (sin guardar .png):
    plot_graph_from_json("kg_pintores_latam.json", max_nodes=100)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[38], line 42
#      32 items_latam_pintores = paginate_search(
#      33     country_qids=latam_country_qids,
#      34     filters={
#    (...)     38     max_entities=10000
#      39 )
#      41 #  Tripletas + JSON
# ---> 42 triplets = fetch_triplets_for_entities([qid for qid, _ in items_latam_pintores])
#      43 graph_latam = build_graph_dict(
#      44     triplets,
#      45     metadata={
#    (...)     48     }
#      49 )
#      50 save_graph_json(graph_latam, "kg_pintores_latam.json")
#
# Cell In[25], line 175, in fetch_triplets_for_entities(item_qids, prop_whitelist)
#     164 # Nota: usamos wdt: (propiedad directa) para simplificar
#     165 query = f"""
#     166 SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
#     167   {values_items}
#    (...)    172 }}
#     173 """.strip()
# --> 175 data = _sparql(query)
#     176 triplets = []
#     177 for b in data["results"]["bindings"]:
#
# Cell In[25], line 27, in _sparql(query, endpoint, throttle_s)
#      25 s.setQuery(query)
#      26 s.setReturnFormat(JSON)
# ---> 27 res = s.query().convert()
#      28 # throttle ligero para ser buen ciudadano con el endpoint
#      29 if throttle_s > 0:
#
# File c:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\.venv\Lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)    958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File c:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\.venv\Lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     296     print("reply:", repr(line))
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#     303     version, status, reason = line.split(None, 2)
#
# RemoteDisconnected: Remote end closed connection without response

# %%
def plot_graph_from_json(
    path: str,
    max_nodes: int = 300,
    label_edges: bool = True,
    k_layout: float = 0.7,
    figsize: Tuple[int, int] = (10, 10)
):
    """
    Carga un .json del KG y lo grafica en una figura de matplotlib (no guarda PNG).
    """
    data = load_graph_json(path)
    G = nx.DiGraph()

    # limitar para plots grandes
    nodes = data["nodes"][:max_nodes]
    node_ids = set(n["id"] for n in nodes)
    id2label = {n["id"]: n["label"] for n in nodes}

    for n in nodes:
        G.add_node(n["id"], label=n["label"], ntype=n["type"])

    for e in data["edges"]:
        if e["source"] in node_ids and e["target"] in node_ids:
            G.add_edge(e["source"], e["target"], label=e["property_label"])

    plt.figure(figsize=figsize)
    pos = nx.spring_layout(G, k=k_layout, seed=42)
    nx.draw(
        G, pos,
        with_labels=True,
        labels=id2label,
        node_size=100,
        node_color="skyblue",
        font_size=6,
        edge_color="gray",
        arrows=True
    )
    if label_edges:
        edge_labels = nx.get_edge_attributes(G, 'label')
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)
    plt.title(data.get("metadata", {}).get("title", "Grafo de Conocimiento"))
    plt.tight_layout()
    plt.show()

# %%
print(f"Encontradas {len(items_latam_pintores)} entidades (pintores de LATAM).")
# Out:
# Encontradas 5778 entidades (pintores de LATAM).

# %%
plot_graph_from_json("kg_pintores_latam.json", max_nodes=100)
# Out:
# C:\Users\tomas\AppData\Local\Temp\ipykernel_25796\3576602809.py:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Scrapping de instrumentos musicales de LATAM (fail test)

# %%
if __name__ == "__main__":

    LATAM_COUNTRIES_QIDS = [
        "Q414","Q750","Q155","Q298","Q739","Q800","Q241","Q736","Q792","Q774",
        "Q783","Q96","Q811","Q804","Q733","Q419","Q786","Q77","Q717"
    ]
    
    instrumento_qid = "Q34379"  # musical instrument
    
    items_instrumentos_latam = paginate_search(
        country_qids=LATAM_COUNTRIES_QIDS,
        filters={
            "P495": LATAM_COUNTRIES_QIDS,
            "P31": [instrumento_qid]
        },
        max_entities=500
    )
    
    triplets_instr = fetch_triplets_for_entities([qid for qid, _ in items_instrumentos_latam])
    graph_instr = build_graph_dict(
        triplets_instr,
        metadata={"title": "Instrumentos musicales latinoamericanos",
                  "filters": {"P495": LATAM_COUNTRIES_QIDS, "P31": [instrumento_qid]}}
    )
    save_graph_json(graph_instr, "kg_instrumentos_latam.json")

# %%
print(f"Encontradas {len(items_latam_instrumentos)} entidades (instrumentos de LATAM).")

# %%
plot_graph_from_json("GC_instrumentos_latam.json", max_nodes=100)

# %% [markdown]
# ## Scrapping sitios de patrimonio mundial (fail test)

# %%
import os, json, time, random, socket
from urllib.error import HTTPError, URLError

CHECKPOINT_DIR = "ckpt_sitios"   # cambia el nombre para otros dominios si quieres
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

def _jsonl_path_items(country_qid, type_qid):
    return os.path.join(CHECKPOINT_DIR, f"items_{country_qid}_{type_qid}.jsonl")

def _jsonl_path_triplets(country_qid, type_qid):
    return os.path.join(CHECKPOINT_DIR, f"triplets_{country_qid}_{type_qid}.jsonl")

def append_jsonl(path, records):
    """Append seguro a JSONL (lista de dicts o strings)."""
    with open(path, "a", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def read_jsonl(path):
    """Lee JSONL si existe, si no devuelve []."""
    out = []
    if not os.path.exists(path):
        return out
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            out.append(json.loads(line))
    return out

def read_qids_from_items_jsonl(path):
    """Devuelve set de QIDs (strings) desde JSONL de items (cada línea es {'qid': 'Qxx'})."""
    qids = set()
    if not os.path.exists(path):
        return qids
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            qid = obj["qid"] if isinstance(obj, dict) else obj
            qids.add(qid)
    return qids

from SPARQLWrapper import SPARQLWrapper, JSON
WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"

def _sparql(query: str, *, endpoint: str = WIKIDATA_ENDPOINT, throttle_s: float = 0.25,
            max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60) -> dict:
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(endpoint)
            s.setQuery(query)
            s.setReturnFormat(JSON)
            try:
                s.setTimeout(timeout_s * 1000)
            except Exception:
                s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0:
                time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep * (2 ** attempt) + random.uniform(0, 0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep)
                continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep * (2 ** attempt) + random.uniform(0, 0.5)
            print(f"[WARN] Error de red: {e}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep)
            continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")


PAGE_SIZE = 150
SLEEP_BETWEEN_PAGES = 0.25

def robust_items_by_country_and_type_checkpointed(
    country_qid: str,
    type_qid: str,
    prop_country: str = "P17",
    prop_type: str = "P31",
    page_size: int = PAGE_SIZE,
    max_per_combo: int = 4000
) -> set:
    """
    Descarga ?item en páginas y guarda cada página en JSONL:
      ckpt_sitios/items_{country}_{type}.jsonl   con líneas: {"qid":"Qxxxx"}
    Reanuda si el archivo ya tiene QIDs.
    Devuelve el set de QIDs acumulados para esa combinación.
    """
    items_path = _jsonl_path_items(country_qid, type_qid)
    seen = read_qids_from_items_jsonl(items_path)  # reanudar
    print(f"   [ckpt] Ya había {len(seen)} QIDs guardados para ({country_qid}, {type_qid})")

    offset = 0
    # Si ya tienes algunos, un truco: avanza offset aproximado en múltiplos de page_size
    # (no perfecto, pero evitamos rehacer demasiadas páginas)
    approx_pages_done = len(seen) // page_size
    offset = approx_pages_done * page_size

    while len(seen) < max_per_combo:
        q = f"""
        SELECT DISTINCT ?item WHERE {{
          VALUES ?country {{ wd:{country_qid} }}
          # ?item wdt:{prop_country} ?country .
          # ?item wdt:{prop_type}/wdt:P279* wd:{type_qid} .
        }}
        LIMIT {page_size}
        OFFSET {offset}
        """
        data = _sparql(q)
        rows = data["results"]["bindings"]
        if not rows:
            break

        page_qids = []
        for b in rows:
            qid = b["item"]["value"].split("/")[-1]
            if qid not in seen:
                seen.add(qid)
                page_qids.append({"qid": qid})

        if page_qids:
            append_jsonl(items_path, page_qids)  # ← GUARDADO INCREMENTAL
            print(f"   [ckpt] Guardada página (offset={offset}), +{len(page_qids)} nuevos, total {len(seen)}")

        offset += page_size
        if SLEEP_BETWEEN_PAGES:
            time.sleep(SLEEP_BETWEEN_PAGES)

    return seen
def robust_multi_country_multi_type_checkpointed(
    country_qids: list,
    type_qids: list,
    prop_country: str = "P17",
    prop_type: str = "P31",
    per_combo_limit: int = 4000
) -> set:
    """
    Itera por país y tipo, usando checkpoint por combinación.
    Devuelve set global de QIDs únicos.
    """
    all_qids = set()
    for cq in country_qids:
        for tq in type_qids:
            print(f"→ País {cq} | Tipo {tq}")
            qids = robust_items_by_country_and_type_checkpointed(
                country_qid=cq,
                type_qid=tq,
                prop_country=prop_country,
                prop_type=prop_type,
                page_size=PAGE_SIZE,
                max_per_combo=per_combo_limit
            )
            print(f"   {len(qids)} items (acumulado global {len(all_qids) + len(qids - all_qids)})")
            all_qids |= qids
    print(f"Total global QIDs únicos: {len(all_qids)}")
    return all_qids
def fetch_triplets_for_entities_batched_with_ckpt(
    item_qids: list,
    country_qid: str,
    type_qid: str,
    batch_size: int = 180
) -> None:
    """
    Descarga tripletas por lotes y guarda en:
      ckpt_sitios/triplets_{country}_{type}.jsonl
    Cada línea es una tripleta dict, compatible con tu build_graph_dict.
    Reanuda saltando QIDs ya procesados (mirando triplets guardadas).
    """
    trip_path = _jsonl_path_triplets(country_qid, type_qid)

    # Identificar QIDs ya procesados leyendo tripletas guardadas
    done = set()
    if os.path.exists(trip_path):
        for t in read_jsonl(trip_path):
            if isinstance(t, dict) and "subject_qid" in t:
                done.add(t["subject_qid"])

    pending = [q for q in item_qids if q not in done]
    print(f"   [trip] {len(done)} sujetos ya procesados, {len(pending)} pendientes.")

    for i in range(0, len(pending), batch_size):
        batch = pending[i:i+batch_size]
        try:
            trip = fetch_triplets_for_entities(batch)  # ← tu función existente
            # Guardar inmediatamente
            append_jsonl(trip_path, trip)
            print(f"   [trip] Guardado lote {i//batch_size+1} ({len(trip)} tripletas) — sujetos {len(done)+len(batch)}")
        except Exception as e:
            print(f"[ERROR] Lote {i//batch_size+1} falló: {e}. Continuando con el siguiente…")
            # seguimos; el checkpoint ya evitó perder lo previo
            continue

# %%
def consolidate_triplets_to_graph_json(output_path: str, title: str, domain_tag: str = "sitios_latam"):
    """
    Lee TODOS los triplets_*.jsonl del CHECKPOINT_DIR, construye nodos/edges
    y guarda un único grafo .json final.
    """
    # Cargar todas las tripletas
    all_triplets = []
    for fname in os.listdir(CHECKPOINT_DIR):
        if fname.startswith("triplets_") and fname.endswith(".jsonl"):
            all_triplets.extend(read_jsonl(os.path.join(CHECKPOINT_DIR, fname)))
    print(f"Consolidando {len(all_triplets)} tripletas…")

    graph = build_graph_dict(all_triplets, metadata={"title": title, "domain": domain_tag})
    save_graph_json(graph, output_path)
    print(f"✅ Guardado: {output_path} (nodos {len(graph['nodes'])}, aristas {len(graph['edges'])})")

# Ejemplo:
# consolidate_triplets_to_graph_json("kg_sitios_interes_latam.json",
#                                    title="Sitios de interés geográfico en LATAM",
#                                    domain_tag="sitios_latam")

# %%
LATAM_COUNTRIES_QIDS = [
    #"Q414","Q750","Q155","Q298","Q739", "Q800", completados -> Q800 falla por mucha info de areas protegidas
    #"Q241","Q736","Q792", -> Q792 falla por mucha info de areas protegidas
    #"Q774","Q783","Q96", "Q811", #-> Q811 falla por mucha info de landmarks
    #"Q804","Q733", -> Q733 falla por mucha info de landmarks
    "Q419","Q786","Q77","Q717"
]


# Define tus tipos concretos de sitios
SITIOS_TIPOS = ["Q570116", "Q2221906", "Q839954"]  # atracción, landmark, área protegida

# 1) Recolección con checkpoint (QIDs únicos globales por conveniencia)
qids_global = robust_multi_country_multi_type_checkpointed(
    country_qids=LATAM_COUNTRIES_QIDS,
    type_qids=SITIOS_TIPOS,
    prop_country="P17",
    prop_type="P31",
    per_combo_limit=2000
)

# 2) Tripletas por combinación país-tipo (usa los JSONL de items ya guardados)
for cq in LATAM_COUNTRIES_QIDS:
    for tq in SITIOS_TIPOS:
        items_path = _jsonl_path_items(cq, tq)
        qids = sorted(read_qids_from_items_jsonl(items_path))
        if not qids:
            continue
        print(f"→ Tripletas ({cq}, {tq}) con {len(qids)} sujetos")
        fetch_triplets_for_entities_batched_with_ckpt(qids, country_qid=cq, type_qid=tq, batch_size=180)
# Out:
# → País Q804 | Tipo Q570116
#    [ckpt] Ya había 0 QIDs guardados para (Q804, Q570116)
#    [ckpt] Guardada página (offset=0), +3 nuevos, total 3
#    3 items (acumulado global 3)
# → País Q804 | Tipo Q2221906
#    [ckpt] Ya había 0 QIDs guardados para (Q804, Q2221906)
#    [ckpt] Guardada página (offset=0), +150 nuevos, total 150
#    [ckpt] Guardada página (offset=150), +147 nuevos, total 297
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
#    [ckpt] Guardada página (offset=300), +53 nuevos, total 350
#    [ckpt] Guardada página (offset=450), +113 nuevos, total 463
#    [ckpt] Guardada página (offset=600), +117 nuevos, total 580
#    [ckpt] Guardada página (offset=750), +56 nuevos, total 636
#    [ckpt] Guardada página (offset=900), +150 nuevos, total 786
#    [ckpt] Guardada página (offset=1050), +85 nuevos, total 871
#    [ckpt] Guardada página (offset=1200), +150 nuevos, total 1021
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
#    [ckpt] Guardada página (offset=1350), +150 nuevos, total 1171
#    [ckpt] Guardada página (offset=1500), +37 nuevos, total 1208
#    [ckpt] Guardada página (offset=1650), +150 nuevos, total 1358
#    [ckpt] Guardada página (offset=1800), +125 nuevos, total 1483
#    [ckpt] Guardada página (offset=1950), +150 nuevos, total 1633
#    [ckpt] Guardada página (offset=2100), +137 nuevos, total 1770
#    [ckpt] Guardada página (offset=2250), +121 nuevos, total 1891
#    [ckpt] Guardada página (offset=2400), +144 nuevos, total 2035
#    2035 items (acumulado global 2038)
# → País Q804 | Tipo Q839954
#    [ckpt] Ya había 0 QIDs guardados para (Q804, Q839954)
#    [ckpt] Guardada página (offset=0), +8 nuevos, total 8
#    8 items (acumulado global 2039)
# → País Q733 | Tipo Q570116
#    [ckpt] Ya había 0 QIDs guardados para (Q733, Q570116)
#    0 items (acumulado global 2039)
# → País Q733 | Tipo Q2221906
#    [ckpt] Ya había 0 QIDs guardados para (Q733, Q2221906)
#    [ckpt] Guardada página (offset=0), +150 nuevos, total 150
#    [ckpt] Guardada página (offset=150), +132 nuevos, total 282
#    [ckpt] Guardada página (offset=300), +124 nuevos, total 406
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
# [WARN] HTTP 429. Reintentando en 2.1s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.7s (intento 3/6)…
#    [ckpt] Guardada página (offset=450), +148 nuevos, total 554
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 1.9s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.5s (intento 3/6)…
# [WARN] HTTP 504. Reintentando en 6.5s (intento 4/6)…
# [WARN] HTTP 504. Reintentando en 13.1s (intento 5/6)…
# [WARN] HTTP 504. Reintentando en 26.1s (intento 6/6)…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[66], line 13
#      10 SITIOS_TIPOS = ["Q570116", "Q2221906", "Q839954"]  # atracción, landmark, área protegida
#      12 # 1) Recolección con checkpoint (QIDs únicos globales por conveniencia)
# ---> 13 qids_global = robust_multi_country_multi_type_checkpointed(
#      14     country_qids=LATAM_COUNTRIES_QIDS,
#      15     type_qids=SITIOS_TIPOS,
#      16     prop_country="P17",
#      17     prop_type="P31",
#      18     per_combo_limit=2000
#      19 )
#      21 # 2) Tripletas por combinación país-tipo (usa los JSONL de items ya guardados)
#      22 for cq in LATAM_COUNTRIES_QIDS:
#
# Cell In[60], line 157, in robust_multi_country_multi_type_checkpointed(country_qids, type_qids, prop_country, prop_type, per_combo_limit)
#     155 for tq in type_qids:
#     156     print(f"→ País {cq} | Tipo {tq}")
# --> 157     qids = robust_items_by_country_and_type_checkpointed(
#     158         country_qid=cq,
#     159         type_qid=tq,
#     160         prop_country=prop_country,
#     161         prop_type=prop_type,
#     162         page_size=PAGE_SIZE,
#     163         max_per_combo=per_combo_limit
#     164     )
#     165     print(f"   {len(qids)} items (acumulado global {len(all_qids) + len(qids - all_qids)})")
#     166     all_qids |= qids
#
# Cell In[60], line 121, in robust_items_by_country_and_type_checkpointed(country_qid, type_qid, prop_country, prop_type, page_size, max_per_combo)
#     111 while len(seen) < max_per_combo:
#     112     q = f"""
#     113     SELECT DISTINCT ?item WHERE {{
#     114       VALUES ?country {{ wd:{country_qid} }}
#    (...)    119     OFFSET {offset}
#     120     """
# --> 121     data = _sparql(q)
#     122     rows = data["results"]["bindings"]
#     123     if not rows:
#
# Cell In[60], line 81, in _sparql(query, endpoint, throttle_s, max_retries, base_sleep, timeout_s)
#      79         time.sleep(sleep)
#      80         continue
# ---> 81 raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")
#
# RuntimeError: SPARQL falló tras 6 reintentos: HTTP Error 504: Gateway Timeout

# %%
import os, glob, re, json

# 👉 tu carpeta en Windows (nota la r'' para evitar problemas de backslashes)
CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios"
assert os.path.isdir(CHECKPOINT_DIR), f"No existe: {CHECKPOINT_DIR}"

# %%
# Encuentra items_* con o sin .jsonl
item_files = glob.glob(os.path.join(CHECKPOINT_DIR, "items_*"))
if not item_files:
    item_files = glob.glob(os.path.join(CHECKPOINT_DIR, "items_*.jsonl"))

print(f"Encontrados {len(item_files)} archivos de items")

# Extrae (country_qid, type_qid) desde el nombre
pairs = []
for f in item_files:
    base = os.path.basename(f)
    m = re.match(r"items_(Q\d+)_(Q\d+)(?:\.jsonl)?$", base)
    if m:
        cq, tq = m.group(1), m.group(2)
        pairs.append((cq, tq, f))
    else:
        print("No pude parsear:", base)

print(f"{len(pairs)} combinaciones (país,tipo) detectadas")
pairs[:5]
# Out:
# Encontrados 41 archivos de items
# 41 combinaciones (país,tipo) detectadas
# [('Q155',
#   'Q2221906',
#   'C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\\items_Q155_Q2221906.jsonl'),
#  ('Q155',
#   'Q570116',
#   'C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\\items_Q155_Q570116.jsonl'),
#  ('Q155',
#   'Q839954',
#   'C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\\items_Q155_Q839954.jsonl'),
#  ('Q241',
#   'Q2221906',
#   'C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\\items_Q241_Q2221906.jsonl'),
#  ('Q241',
#   'Q570116',
#   'C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\\items_Q241_Q570116.jsonl')]

# %%
def read_qids_generic(items_path: str):
    qids = set()
    with open(items_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            # Primero intentamos JSON
            try:
                obj = json.loads(line)
                if isinstance(obj, dict) and "qid" in obj:
                    qids.add(obj["qid"])
                    continue
                # Si fuera un string JSON "Q123"
                if isinstance(obj, str) and obj.startswith("Q"):
                    qids.add(obj)
                    continue
            except Exception:
                pass
            # Fallback: parsear “Q\d+” crudo
            m = re.search(r"(Q\d+)", line)
            if m:
                qids.add(m.group(1))
    return sorted(qids)

# %%
# Si no la tienes definida, vuelve a definirla rápido:
def load_graph_json(path: str):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)

def save_graph_json(graph_dict: dict, path: str):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(graph_dict, f, ensure_ascii=False, indent=2)

def build_graph_dict(triplets, metadata=None):
    nodes = {}
    edges = []
    def add_node(node_id, label, is_entity):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}
    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True)
            tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False)
            tgt = o
        edges.append({"source": s, "target": tgt, "property_pid": t["property_pid"], "property_label": t["property_label"]})
    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_path: str, title: str, domain_tag: str = "sitios_latam"):
    # Lee todos los triplets_*.jsonl en CHECKPOINT_DIR
    all_triplets = []
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f, "r", encoding="utf-8") as fh:
            for line in fh:
                try:
                    obj = json.loads(line)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_triplets.append(obj)
                except Exception:
                    pass
    print(f"Consolidando {len(all_triplets)} tripletas…")
    graph = build_graph_dict(all_triplets, metadata={"title": title, "domain": domain_tag})
    save_graph_json(graph, output_path)
    print(f"✅ Guardado: {output_path} (nodos {len(graph['nodes'])}, aristas {len(graph['edges'])})")

# Llamada de consolidación:
salida = os.path.join(CHECKPOINT_DIR, "kg_sitios_interes_latam.json")
consolidate_triplets_to_graph_json(salida, title="Sitios de interés geográfico en LATAM", domain_tag="sitios_latam")
# Out:
# Consolidando 0 tripletas…
# ✅ Guardado: C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\kg_sitios_interes_latam.json (nodos 0, aristas 0)

# %%
print(f"Encontradas {len(items_sitios_latam)} entidades (instrumentos de LATAM).")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(f"Encontradas {len(items_sitios_latam)} entidades (instrumentos de LATAM).")
#
# NameError: name 'items_sitios_latam' is not defined

# %%
consolidate_triplets_to_graph_json("kg_sitios_interes_latam.json",
                                    title="Sitios de interés geográfico en LATAM",
                                    domain_tag="sitios_latam")
# Out:
# Consolidando 0 tripletas…
# ✅ Guardado: kg_sitios_interes_latam.json (nodos 0, aristas 0)

# %%
plot_graph_from_json("GC_instrumentos_latam.json", max_nodes=100)

# %% [markdown]
# ## Scrapping de landmarks LATAM

# %%
# -*- coding: utf-8 -*-
import os, re, json, time, random, socket, glob
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# ========= CONFIG =========
CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

LATAM_COUNTRIES_QIDS = [
    #"Q414","Q750","Q155","Q298","Q739","Q800", <- completados, se demoraron 100 minn
    #"Q241", -> Q241 falla por mucha info de landmarks
    #"Q736","Q792","Q774", -> Q774 falla por mucha info
    "Q783","Q96","Q811","Q804","Q733","Q419","Q786","Q77","Q717"
]

# Ejemplos (elige 1 o varios). Para bajar carga, empieza con UNO:
#   "Q2221906" = landmark
#   "Q570116"  = tourist attraction
#   "Q839954"  = protected area
TYPE_QIDS = ["Q2221906"]   # <-- prueba con uno; luego agrega más si quieres

PROP_COUNTRY = "P17"       # sitios -> país donde está ubicado
PROP_TYPE    = "P31"       # instancia de
PAGE_SIZE    = 150         # página SPARQL
PER_COMBO_MAX = 4000       # máximo por (país,tipo)
TRIPLET_BATCH = 180        # batch para pedir tripletas
SLEEP_BETWEEN_PAGES = 0.25

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

# ========= UTILIDADES SPARQL ROBUSTO =========
def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try:
                s.setTimeout(timeout_s * 1000)
            except Exception:
                s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0:
                time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# ========= JSONL / OFFSET CHECKPOINT =========
def _items_path(cq, tq):     return os.path.join(CHECKPOINT_DIR, f"items_{cq}_{tq}.jsonl")
def _triplets_path(cq, tq):  return os.path.join(CHECKPOINT_DIR, f"triplets_{cq}_{tq}.jsonl")
def _offset_path(cq, tq):    return os.path.join(CHECKPOINT_DIR, f"offset_{cq}_{tq}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_jsonl(path):
    out=[]
    if not os.path.exists(path): return out
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line=line.strip()
            if not line: continue
            out.append(json.loads(line))
    return out

def _read_done_subjects(trip_path):
    done=set()
    if not os.path.exists(trip_path): return done
    with open(trip_path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(cq,tq):
    p=_offset_path(cq,tq)
    if not os.path.exists(p): return 0
    try:
        return int(open(p,"r").read().strip())
    except:
        return 0

def _write_offset(cq,tq,offset):
    with open(_offset_path(cq,tq),"w") as f:
        f.write(str(offset))

# ========= TRIPLETAS (igual “que antes”) =========
DEFAULT_PROP_WHITELIST = [
    "P31","P106","P136","P495","P27","P19","P20","P69","P166","P737","P739",
    "P135","P1303","P264","P451","P800","P279","P361","P131"
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or DEFAULT_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)

    # sin labels para items muy grandes sería más liviano, pero aquí sí los queremos (como antes)
    query = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(query)
    trip=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        p_iri  = b["p"]["value"]
        pid    = p_iri.split("/")[-1]
        pid    = pid.split(":")[-1] if ":" in pid else pid
        p_lab  = b.get("propLabel",{}).get("value", pid)
        o_val  = b["o"]["value"]
        o_lab  = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        trip.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return trip

# ========= PÁGINAS DE ÍTEMS (SOLO IDs) =========
def fetch_items_page(country_qid: str, type_qid: str, offset: int, limit: int,
                     prop_country: str=PROP_COUNTRY, prop_type: str=PROP_TYPE) -> List[str]:
    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{country_qid} }}
      # ?item wdt:{prop_country} ?country .
      # ?item wdt:{prop_type}/wdt:P279* wd:{type_qid} .
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]

# ========= STREAMING POR (PAÍS, TIPO) CON CHECKPOINT REAL =========
def stream_country_type(cq: str, tq: str,
                        per_combo_max: int=PER_COMBO_MAX,
                        page_size: int=PAGE_SIZE,
                        triplet_batch: int=TRIPLET_BATCH):
    off = _read_offset(cq,tq)
    items_file = _items_path(cq,tq)
    trips_file = _triplets_path(cq,tq)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ ({cq},{tq}) reanudando desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page(cq, tq, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        # guarda la página de items (por trazabilidad) — opcional
        _append_jsonl(items_file, [{"qid": q} for q in ids])
        # filtra los que faltan tripletas
        pend = [q for q in ids if q not in done]
        if pend:
            # por lotes de tripletas
            for i in range(0, len(pend), triplet_batch):
                chunk = pend[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk)
                    if trip:
                        _append_jsonl(trips_file, trip)      # ← GUARDA TRIPLETAS INMEDIATO
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch de tripletas en offset {off}: {e}; sigo…")
                    time.sleep(1.0)
        else:
            print(f"   [skip] página offset {off} ya cubierta por checkpoint")

        off += page_size
        _write_offset(cq,tq,off)            # ← ACTUALIZA OFFSET TRAS CADA PÁGINA
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_combo_max:
            print(f"   [cut] alcance per_combo_max={per_combo_max}"); break

    print(f"✔ ({cq},{tq}) streaming listo. Tripletas nuevas en esta corrida: {total_new}")

# ========= CONSOLIDACIÓN A KG (nodes/edges) =========
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}
    edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}

    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True)
            tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt, "property_pid": t["property_pid"], "property_label": t["property_label"]})

    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_path: str, title: str, domain_tag: str):
    # Lee TODOS los triplets_*.jsonl del CHECKPOINT_DIR
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    with open(output_path,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {output_path} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

# %%
for cq in LATAM_COUNTRIES_QIDS:
    for tq in TYPE_QIDS:  # ["Q2221906"] ahora
        stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
# Out:
# → (Q414,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +401 tripletas (sujetos 150), offset 0
#    [trip] +277 tripletas (sujetos 300), offset 150
#    [trip] +282 tripletas (sujetos 415), offset 300
#    [trip] +326 tripletas (sujetos 565), offset 450
#    [trip] +341 tripletas (sujetos 715), offset 600
#    [trip] +342 tripletas (sujetos 864), offset 750
#    [trip] +352 tripletas (sujetos 1014), offset 900
#    [trip] +295 tripletas (sujetos 1138), offset 1050
#    [trip] +117 tripletas (sujetos 1188), offset 1200
#    [trip] +292 tripletas (sujetos 1296), offset 1350
#    [trip] +379 tripletas (sujetos 1436), offset 1500
#    [trip] +100 tripletas (sujetos 1486), offset 1650
#    [trip] +153 tripletas (sujetos 1545), offset 1800
#    [trip] +408 tripletas (sujetos 1695), offset 1950
#    [trip] +302 tripletas (sujetos 1804), offset 2100
#    [trip] +147 tripletas (sujetos 1853), offset 2250
#    [trip] +150 tripletas (sujetos 1912), offset 2400
#    [trip] +320 tripletas (sujetos 2038), offset 2550
#    [trip] +163 tripletas (sujetos 2118), offset 2700
#    [skip] página offset 2850 ya cubierta por checkpoint
#    [trip] +158 tripletas (sujetos 2197), offset 3000
#    [trip] +296 tripletas (sujetos 2345), offset 3150
#    [trip] +138 tripletas (sujetos 2415), offset 3300
#    [trip] +255 tripletas (sujetos 2542), offset 3450
#    [trip] +146 tripletas (sujetos 2615), offset 3600
#    [trip] +299 tripletas (sujetos 2765), offset 3750
#    [trip] +274 tripletas (sujetos 2904), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q414,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6713
# → (Q750,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +312 tripletas (sujetos 150), offset 0
#    [trip] +283 tripletas (sujetos 297), offset 150
#    [trip] +275 tripletas (sujetos 435), offset 300
#    [trip] +264 tripletas (sujetos 569), offset 450
#    [trip] +232 tripletas (sujetos 685), offset 600
#    [trip] +300 tripletas (sujetos 834), offset 750
#    [trip] +340 tripletas (sujetos 979), offset 900
#    [trip] +252 tripletas (sujetos 1128), offset 1050
#    [trip] +241 tripletas (sujetos 1258), offset 1200
#    [trip] +175 tripletas (sujetos 1343), offset 1350
#    [trip] +270 tripletas (sujetos 1476), offset 1500
#    [trip] +299 tripletas (sujetos 1626), offset 1650
#    [trip] +145 tripletas (sujetos 1700), offset 1800
#    [trip] +183 tripletas (sujetos 1850), offset 1950
#    [trip] +193 tripletas (sujetos 1999), offset 2100
#    [trip] +215 tripletas (sujetos 2115), offset 2250
#    [trip] +295 tripletas (sujetos 2265), offset 2400
#    [trip] +189 tripletas (sujetos 2371), offset 2550
#    [trip] +131 tripletas (sujetos 2437), offset 2700
#    [trip] +243 tripletas (sujetos 2576), offset 2850
#    [trip] +247 tripletas (sujetos 2702), offset 3000
#    [trip] +118 tripletas (sujetos 2768), offset 3150
#    [trip] +297 tripletas (sujetos 2918), offset 3300
#    [trip] +297 tripletas (sujetos 3068), offset 3450
#    [trip] +259 tripletas (sujetos 3198), offset 3600
#    [trip] +93 tripletas (sujetos 3244), offset 3750
#    [trip] +100 tripletas (sujetos 3295), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q750,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6248
# → (Q155,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +441 tripletas (sujetos 150), offset 0
#    [trip] +365 tripletas (sujetos 291), offset 150
#    [trip] +209 tripletas (sujetos 434), offset 300
#    [trip] +374 tripletas (sujetos 583), offset 450
#    [trip] +457 tripletas (sujetos 733), offset 600
#    [trip] +427 tripletas (sujetos 872), offset 750
#    [trip] +208 tripletas (sujetos 955), offset 900
#    [trip] +300 tripletas (sujetos 1105), offset 1050
#    [trip] +30 tripletas (sujetos 1120), offset 1200
#    [trip] +205 tripletas (sujetos 1223), offset 1350
#    [trip] +156 tripletas (sujetos 1298), offset 1500
#    [trip] +316 tripletas (sujetos 1448), offset 1650
#    [trip] +421 tripletas (sujetos 1598), offset 1800
#    [trip] +451 tripletas (sujetos 1748), offset 1950
#    [trip] +342 tripletas (sujetos 1862), offset 2100
#    [trip] +339 tripletas (sujetos 1975), offset 2250
#    [trip] +382 tripletas (sujetos 2106), offset 2400
#    [trip] +153 tripletas (sujetos 2157), offset 2550
#    [trip] +313 tripletas (sujetos 2261), offset 2700
#    [trip] +400 tripletas (sujetos 2395), offset 2850
#    [trip] +426 tripletas (sujetos 2538), offset 3000
#    [trip] +432 tripletas (sujetos 2686), offset 3150
#    [trip] +294 tripletas (sujetos 2784), offset 3300
#    [trip] +378 tripletas (sujetos 2934), offset 3450
#    [trip] +313 tripletas (sujetos 3084), offset 3600
#    [trip] +534 tripletas (sujetos 3232), offset 3750
#    [trip] +144 tripletas (sujetos 3296), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q155,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 8810
# → (Q298,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +337 tripletas (sujetos 150), offset 0
#    [trip] +302 tripletas (sujetos 295), offset 150
#    [trip] +280 tripletas (sujetos 439), offset 300
#    [trip] +366 tripletas (sujetos 588), offset 450
#    [trip] +321 tripletas (sujetos 734), offset 600
#    [trip] +250 tripletas (sujetos 877), offset 750
#    [trip] +273 tripletas (sujetos 1012), offset 900
#    [trip] +153 tripletas (sujetos 1087), offset 1050
#    [trip] +211 tripletas (sujetos 1230), offset 1200
#    [trip] +428 tripletas (sujetos 1379), offset 1350
#    [trip] +305 tripletas (sujetos 1528), offset 1500
#    [trip] +117 tripletas (sujetos 1568), offset 1650
#    [trip] +239 tripletas (sujetos 1691), offset 1800
#    [trip] +286 tripletas (sujetos 1840), offset 1950
#    [trip] +237 tripletas (sujetos 1964), offset 2100
#    [trip] +287 tripletas (sujetos 2113), offset 2250
#    [trip] +197 tripletas (sujetos 2216), offset 2400
#    [trip] +192 tripletas (sujetos 2314), offset 2550
#    [trip] +272 tripletas (sujetos 2458), offset 2700
#    [trip] +291 tripletas (sujetos 2608), offset 2850
#    [trip] +85 tripletas (sujetos 2653), offset 3000
#    [trip] +95 tripletas (sujetos 2701), offset 3150
#    [trip] +187 tripletas (sujetos 2799), offset 3300
#    [trip] +285 tripletas (sujetos 2949), offset 3450
#    [trip] +294 tripletas (sujetos 3099), offset 3600
#    [trip] +210 tripletas (sujetos 3207), offset 3750
#    [trip] +290 tripletas (sujetos 3356), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q298,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6790
# → (Q739,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +348 tripletas (sujetos 150), offset 0
#    [trip] +354 tripletas (sujetos 300), offset 150
#    [trip] +331 tripletas (sujetos 447), offset 300
#    [trip] +200 tripletas (sujetos 547), offset 450
#    [trip] +197 tripletas (sujetos 647), offset 600
#    [trip] +231 tripletas (sujetos 796), offset 750
#    [trip] +184 tripletas (sujetos 918), offset 900
#    [trip] +274 tripletas (sujetos 1065), offset 1050
#    [trip] +260 tripletas (sujetos 1195), offset 1200
#    [trip] +176 tripletas (sujetos 1283), offset 1350
#    [trip] +174 tripletas (sujetos 1371), offset 1500
#    [trip] +129 tripletas (sujetos 1458), offset 1650
#    [trip] +264 tripletas (sujetos 1592), offset 1800
#    [trip] +328 tripletas (sujetos 1742), offset 1950
#    [trip] +317 tripletas (sujetos 1892), offset 2100
#    [trip] +360 tripletas (sujetos 2042), offset 2250
#    [trip] +318 tripletas (sujetos 2191), offset 2400
#    [trip] +114 tripletas (sujetos 2248), offset 2550
#    [trip] +395 tripletas (sujetos 2380), offset 2700
#    [trip] +309 tripletas (sujetos 2504), offset 2850
#    [trip] +447 tripletas (sujetos 2654), offset 3000
#    [trip] +234 tripletas (sujetos 2733), offset 3150
#    [trip] +298 tripletas (sujetos 2833), offset 3300
#    [trip] +147 tripletas (sujetos 2882), offset 3450
#    [trip] +291 tripletas (sujetos 3028), offset 3600
#    [trip] +327 tripletas (sujetos 3178), offset 3750
#    [trip] +142 tripletas (sujetos 3233), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q739,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 7149
# → (Q800,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +294 tripletas (sujetos 150), offset 0
#    [trip] +296 tripletas (sujetos 300), offset 150
#    [trip] +300 tripletas (sujetos 450), offset 300
#    [trip] +199 tripletas (sujetos 551), offset 450
#    [trip] +285 tripletas (sujetos 700), offset 600
#    [trip] +294 tripletas (sujetos 848), offset 750
#    [trip] +291 tripletas (sujetos 991), offset 900
#    [trip] +264 tripletas (sujetos 1116), offset 1050
#    [trip] +240 tripletas (sujetos 1241), offset 1200
#    [trip] +323 tripletas (sujetos 1390), offset 1350
#    [trip] +155 tripletas (sujetos 1463), offset 1500
#    [trip] +294 tripletas (sujetos 1602), offset 1650
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
#    [trip] +195 tripletas (sujetos 1705), offset 1800
# [WARN] HTTP 504. Reintentando en 0.8s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 1.9s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.7s (intento 3/6)…
# [WARN] HTTP 504. Reintentando en 6.8s (intento 4/6)…
#    [fin] no hay más páginas.
# ✔ (Q800,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 3430
# → (Q241,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +310 tripletas (sujetos 150), offset 0
#    [trip] +337 tripletas (sujetos 300), offset 150
#    [trip] +275 tripletas (sujetos 448), offset 300
#    [trip] +290 tripletas (sujetos 598), offset 450
#    [trip] +170 tripletas (sujetos 686), offset 600
#    [trip] +286 tripletas (sujetos 833), offset 750
#    [trip] +285 tripletas (sujetos 982), offset 900
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
#    [trip] +173 tripletas (sujetos 1070), offset 1050
#    [trip] +189 tripletas (sujetos 1168), offset 1200
#    [trip] +293 tripletas (sujetos 1318), offset 1350
#    [trip] +214 tripletas (sujetos 1427), offset 1500
#    [trip] +109 tripletas (sujetos 1481), offset 1650
#    [trip] +343 tripletas (sujetos 1631), offset 1800
#    [trip] +290 tripletas (sujetos 1781), offset 1950
#    [trip] +290 tripletas (sujetos 1931), offset 2100
#    [trip] +293 tripletas (sujetos 2081), offset 2250
#    [trip] +230 tripletas (sujetos 2207), offset 2400
#    [trip] +113 tripletas (sujetos 2266), offset 2550
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
#    [trip] +200 tripletas (sujetos 2369), offset 2700
#    [skip] página offset 2850 ya cubierta por checkpoint
#    [trip] +103 tripletas (sujetos 2424), offset 3000
#    [trip] +202 tripletas (sujetos 2530), offset 3150
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
#    [trip] +294 tripletas (sujetos 2679), offset 3300
# [WARN] HTTP 504. Reintentando en 1.1s (intento 1/6)…
#    [trip] +315 tripletas (sujetos 2829), offset 3450
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
#    [trip] +316 tripletas (sujetos 2978), offset 3600
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
#    [trip] +351 tripletas (sujetos 3093), offset 3750
# [WARN] HTTP 504. Reintentando en 0.8s (intento 1/6)…
#    [trip] +238 tripletas (sujetos 3215), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q241,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6509
# → (Q736,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +322 tripletas (sujetos 150), offset 0
#    [trip] +347 tripletas (sujetos 300), offset 150
#    [trip] +345 tripletas (sujetos 440), offset 300
#    [trip] +351 tripletas (sujetos 590), offset 450
#    [trip] +237 tripletas (sujetos 687), offset 600
#    [trip] +358 tripletas (sujetos 823), offset 750
#    [trip] +271 tripletas (sujetos 938), offset 900
#    [trip] +164 tripletas (sujetos 1003), offset 1050
#    [trip] +212 tripletas (sujetos 1088), offset 1200
#    [trip] +277 tripletas (sujetos 1238), offset 1350
#    [trip] +299 tripletas (sujetos 1388), offset 1500
#    [trip] +301 tripletas (sujetos 1538), offset 1650
#    [trip] +318 tripletas (sujetos 1688), offset 1800
#    [trip] +259 tripletas (sujetos 1818), offset 1950
#    [trip] +279 tripletas (sujetos 1959), offset 2100
#    [trip] +212 tripletas (sujetos 2067), offset 2250
#    [trip] +294 tripletas (sujetos 2217), offset 2400
#    [trip] +244 tripletas (sujetos 2367), offset 2550
#    [trip] +283 tripletas (sujetos 2513), offset 2700
#    [trip] +169 tripletas (sujetos 2600), offset 2850
#    [trip] +296 tripletas (sujetos 2749), offset 3000
#    [trip] +261 tripletas (sujetos 2882), offset 3150
# [WARN] HTTP 504. Reintentando en 1.1s (intento 1/6)…
#    [trip] +78 tripletas (sujetos 2925), offset 3300
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 2.0s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.4s (intento 3/6)…
#    [fin] no hay más páginas.
# ✔ (Q736,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6177
# → (Q792,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +369 tripletas (sujetos 150), offset 0
#    [trip] +385 tripletas (sujetos 296), offset 150
#    [trip] +331 tripletas (sujetos 446), offset 300
#    [trip] +291 tripletas (sujetos 592), offset 450
#    [trip] +221 tripletas (sujetos 691), offset 600
#    [trip] +295 tripletas (sujetos 838), offset 750
#    [trip] +176 tripletas (sujetos 926), offset 900
#    [trip] +280 tripletas (sujetos 1067), offset 1050
#    [trip] +270 tripletas (sujetos 1202), offset 1200
#    [trip] +281 tripletas (sujetos 1352), offset 1350
#    [trip] +309 tripletas (sujetos 1499), offset 1500
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
# [WARN] HTTP 429. Reintentando en 1.8s (intento 2/6)…
#    [trip] +74 tripletas (sujetos 1532), offset 1650
#    [fin] no hay más páginas.
# ✔ (Q792,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 3282
# → (Q774,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +320 tripletas (sujetos 150), offset 0
#    [trip] +302 tripletas (sujetos 300), offset 150
#    [trip] +285 tripletas (sujetos 450), offset 300
#    [trip] +300 tripletas (sujetos 600), offset 450
#    [trip] +298 tripletas (sujetos 749), offset 600
#    [trip] +290 tripletas (sujetos 896), offset 750
#    [trip] +261 tripletas (sujetos 1029), offset 900
#    [trip] +299 tripletas (sujetos 1179), offset 1050
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 for cq in LATAM_COUNTRIES_QIDS:
#       2     for tq in TYPE_QIDS:  # ["Q2221906"] ahora
# ----> 3         stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
#
# Cell In[8], line 185, in stream_country_type(cq, tq, per_combo_max, page_size, triplet_batch)
#     182 print(f"→ ({cq},{tq}) reanudando desde offset {off}, sujetos ya con tripletas: {len(done)}")
#     184 while True:
# --> 185     ids = fetch_items_page(cq, tq, offset=off, limit=page_size)
#     186     if not ids:
#     187         print("   [fin] no hay más páginas."); break
#
# Cell In[8], line 168, in fetch_items_page(country_qid, type_qid, offset, limit, prop_country, prop_type)
#     157 def fetch_items_page(country_qid: str, type_qid: str, offset: int, limit: int,
#     158                      prop_country: str=PROP_COUNTRY, prop_type: str=PROP_TYPE) -> List[str]:
#     159     q = f"""
#     160     SELECT DISTINCT ?item WHERE {{
#     161       VALUES ?country {{ wd:{country_qid} }}
#    (...)    166     OFFSET {offset}
#     167     """
# --> 168     data = _sparql(q)
#     169     return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
#
# Cell In[8], line 45, in _sparql(query, throttle_s, max_retries, base_sleep, timeout_s)
#      43     s.setTimeout(timeout_s)
#      44 s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
# ---> 45 res = s.query().convert()
#      46 if throttle_s > 0:
#      47     time.sleep(throttle_s)
#
# File c:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\.venv\Lib\site-packages\SPARQLWrapper\Wrapper.py:1196, in QueryResult.convert(self)
#    1194 elif _content_type_in_list(ct, _SPARQL_JSON):
#    1195     _validate_format("JSON", [JSON], ct, self.requestedFormat)
# -> 1196     return self._convertJSON()
#    1197 elif _content_type_in_list(ct, _RDF_XML):
#    1198     _validate_format(
#    1199         "RDF/XML", [RDF, XML, RDFXML], ct, self.requestedFormat
#    1200     )
#
# File c:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\.venv\Lib\site-packages\SPARQLWrapper\Wrapper.py:1059, in QueryResult._convertJSON(self)
#    1051 def _convertJSON(self) -> Dict[Any, Any]:
#    1052     """
#    1053     Convert a JSON result into a Python dict. This method can be overwritten in a subclass
#    1054     for a different conversion method.
#    (...)   1057     :rtype: dict
#    1058     """
# -> 1059     json_str = json.loads(self.response.read().decode("utf-8"))
#    1060     if isinstance(json_str, dict):
#    1061         return json_str
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 758 column 2 (char 17729)

# %%
for cq in LATAM_COUNTRIES_QIDS:
    for tq in TYPE_QIDS:  # ["Q2221906"] ahora
        stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
# Out:
# → (Q241,Q2221906) reanudando desde offset 4050, sujetos ya con tripletas: 3215
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
# [WARN] HTTP 429. Reintentando en 1.8s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.5s (intento 3/6)…
# [WARN] HTTP 504. Reintentando en 6.7s (intento 4/6)…
# [WARN] HTTP 504. Reintentando en 13.2s (intento 5/6)…
# [WARN] HTTP 504. Reintentando en 25.6s (intento 6/6)…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 3
#       1 for cq in LATAM_COUNTRIES_QIDS:
#       2     for tq in TYPE_QIDS:  # ["Q2221906"] ahora
# ----> 3         stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
#
# Cell In[10], line 186, in stream_country_type(cq, tq, per_combo_max, page_size, triplet_batch)
#     183 print(f"→ ({cq},{tq}) reanudando desde offset {off}, sujetos ya con tripletas: {len(done)}")
#     185 while True:
# --> 186     ids = fetch_items_page(cq, tq, offset=off, limit=page_size)
#     187     if not ids:
#     188         print("   [fin] no hay más páginas."); break
#
# Cell In[10], line 169, in fetch_items_page(country_qid, type_qid, offset, limit, prop_country, prop_type)
#     158 def fetch_items_page(country_qid: str, type_qid: str, offset: int, limit: int,
#     159                      prop_country: str=PROP_COUNTRY, prop_type: str=PROP_TYPE) -> List[str]:
#     160     q = f"""
#     161     SELECT DISTINCT ?item WHERE {{
#     162       VALUES ?country {{ wd:{country_qid} }}
#    (...)    167     OFFSET {offset}
#     168     """
# --> 169     data = _sparql(q)
#     170     return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
#
# Cell In[10], line 62, in _sparql(query, throttle_s, max_retries, base_sleep, timeout_s)
#      60         print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
#      61         time.sleep(sleep); continue
# ---> 62 raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")
#
# RuntimeError: SPARQL falló tras 6 reintentos: HTTP Error 504: Gateway Timeout

# %%
for cq in LATAM_COUNTRIES_QIDS:
    for tq in TYPE_QIDS:  # ["Q2221906"] ahora
        stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
# Out:
# → (Q736,Q2221906) reanudando desde offset 3450, sujetos ya con tripletas: 2925
#    [fin] no hay más páginas.
# ✔ (Q736,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 0
# → (Q792,Q2221906) reanudando desde offset 1800, sujetos ya con tripletas: 1532
#    [fin] no hay más páginas.
# ✔ (Q792,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 0
# → (Q774,Q2221906) reanudando desde offset 1200, sujetos ya con tripletas: 1179
#    [trip] +333 tripletas (sujetos 1329), offset 1200
#    [trip] +113 tripletas (sujetos 1384), offset 1350
#    [trip] +205 tripletas (sujetos 1525), offset 1500
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
# [WARN] HTTP 429. Reintentando en 1.9s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.2s (intento 3/6)…
# [WARN] HTTP 504. Reintentando en 6.7s (intento 4/6)…
# [WARN] HTTP 504. Reintentando en 13.0s (intento 5/6)…
# [WARN] HTTP 429. Reintentando en 25.6s (intento 6/6)…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 3
#       1 for cq in LATAM_COUNTRIES_QIDS:
#       2     for tq in TYPE_QIDS:  # ["Q2221906"] ahora
# ----> 3         stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
#
# Cell In[12], line 187, in stream_country_type(cq, tq, per_combo_max, page_size, triplet_batch)
#     184 print(f"→ ({cq},{tq}) reanudando desde offset {off}, sujetos ya con tripletas: {len(done)}")
#     186 while True:
# --> 187     ids = fetch_items_page(cq, tq, offset=off, limit=page_size)
#     188     if not ids:
#     189         print("   [fin] no hay más páginas."); break
#
# Cell In[12], line 170, in fetch_items_page(country_qid, type_qid, offset, limit, prop_country, prop_type)
#     159 def fetch_items_page(country_qid: str, type_qid: str, offset: int, limit: int,
#     160                      prop_country: str=PROP_COUNTRY, prop_type: str=PROP_TYPE) -> List[str]:
#     161     q = f"""
#     162     SELECT DISTINCT ?item WHERE {{
#     163       VALUES ?country {{ wd:{country_qid} }}
#    (...)    168     OFFSET {offset}
#     169     """
# --> 170     data = _sparql(q)
#     171     return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
#
# Cell In[12], line 63, in _sparql(query, throttle_s, max_retries, base_sleep, timeout_s)
#      61         print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
#      62         time.sleep(sleep); continue
# ---> 63 raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")
#
# RuntimeError: SPARQL falló tras 6 reintentos: HTTP Error 429: Too Many Requests

# %%
for cq in LATAM_COUNTRIES_QIDS:
    for tq in TYPE_QIDS:  # ["Q2221906"] ahora
        stream_country_type(cq, tq, per_combo_max=PER_COMBO_MAX, page_size=PAGE_SIZE, triplet_batch=TRIPLET_BATCH)
# Out:
# → (Q783,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +317 tripletas (sujetos 150), offset 0
#    [trip] +305 tripletas (sujetos 300), offset 150
#    [trip] +296 tripletas (sujetos 446), offset 300
#    [trip] +300 tripletas (sujetos 596), offset 450
#    [trip] +194 tripletas (sujetos 693), offset 600
#    [trip] +300 tripletas (sujetos 843), offset 750
#    [trip] +168 tripletas (sujetos 927), offset 900
#    [trip] +265 tripletas (sujetos 1060), offset 1050
#    [trip] +143 tripletas (sujetos 1132), offset 1200
#    [trip] +294 tripletas (sujetos 1279), offset 1350
#    [trip] +196 tripletas (sujetos 1377), offset 1500
#    [trip] +302 tripletas (sujetos 1527), offset 1650
#    [trip] +230 tripletas (sujetos 1642), offset 1800
#    [trip] +158 tripletas (sujetos 1721), offset 1950
#    [trip] +178 tripletas (sujetos 1810), offset 2100
# [WARN] HTTP 504. Reintentando en 0.8s (intento 1/6)…
#    [trip] +178 tripletas (sujetos 1899), offset 2250
#    [trip] +299 tripletas (sujetos 2049), offset 2400
#    [trip] +239 tripletas (sujetos 2169), offset 2550
#    [trip] +298 tripletas (sujetos 2319), offset 2700
#    [trip] +272 tripletas (sujetos 2463), offset 2850
#    [trip] +313 tripletas (sujetos 2613), offset 3000
#    [trip] +302 tripletas (sujetos 2763), offset 3150
# [WARN] HTTP 504. Reintentando en 0.9s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 2.1s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.3s (intento 3/6)…
# [WARN] HTTP 504. Reintentando en 6.8s (intento 4/6)…
# [WARN] HTTP 504. Reintentando en 13.1s (intento 5/6)…
#    [trip] +178 tripletas (sujetos 2859), offset 3300
#    [fin] no hay más páginas.
# ✔ (Q783,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 5725
# → (Q96,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +384 tripletas (sujetos 150), offset 0
#    [trip] +327 tripletas (sujetos 299), offset 150
#    [trip] +376 tripletas (sujetos 449), offset 300
#    [trip] +270 tripletas (sujetos 578), offset 450
#    [trip] +300 tripletas (sujetos 728), offset 600
#    [trip] +150 tripletas (sujetos 803), offset 750
#    [trip] +244 tripletas (sujetos 925), offset 900
#    [trip] +152 tripletas (sujetos 985), offset 1050
#    [trip] +310 tripletas (sujetos 1134), offset 1200
#    [trip] +314 tripletas (sujetos 1284), offset 1350
#    [trip] +324 tripletas (sujetos 1434), offset 1500
#    [trip] +299 tripletas (sujetos 1582), offset 1650
#    [trip] +290 tripletas (sujetos 1730), offset 1800
#    [trip] +344 tripletas (sujetos 1870), offset 1950
#    [trip] +147 tripletas (sujetos 1941), offset 2100
#    [trip] +340 tripletas (sujetos 2090), offset 2250
#    [skip] página offset 2400 ya cubierta por checkpoint
#    [trip] +218 tripletas (sujetos 2189), offset 2550
#    [trip] +41 tripletas (sujetos 2209), offset 2700
#    [trip] +216 tripletas (sujetos 2314), offset 2850
#    [trip] +315 tripletas (sujetos 2464), offset 3000
#    [trip] +163 tripletas (sujetos 2544), offset 3150
#    [trip] +102 tripletas (sujetos 2594), offset 3300
#    [trip] +309 tripletas (sujetos 2744), offset 3450
#    [trip] +82 tripletas (sujetos 2784), offset 3600
#    [trip] +306 tripletas (sujetos 2933), offset 3750
#    [trip] +115 tripletas (sujetos 2984), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q96,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 6438
# → (Q811,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +402 tripletas (sujetos 150), offset 0
#    [trip] +346 tripletas (sujetos 300), offset 150
#    [trip] +332 tripletas (sujetos 450), offset 300
#    [trip] +98 tripletas (sujetos 499), offset 450
#    [trip] +322 tripletas (sujetos 649), offset 600
#    [trip] +190 tripletas (sujetos 731), offset 750
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
#    [trip] +311 tripletas (sujetos 868), offset 900
#    [trip] +395 tripletas (sujetos 1017), offset 1050
# [WARN] HTTP 504. Reintentando en 1.1s (intento 1/6)…
#    [trip] +265 tripletas (sujetos 1158), offset 1200
#    [trip] +266 tripletas (sujetos 1296), offset 1350
#    [trip] +266 tripletas (sujetos 1435), offset 1500
#    [trip] +326 tripletas (sujetos 1585), offset 1650
#    [trip] +321 tripletas (sujetos 1735), offset 1800
#    [trip] +237 tripletas (sujetos 1853), offset 1950
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 1.9s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.3s (intento 3/6)…
#    [fin] no hay más páginas.
# ✔ (Q811,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 4077
# → (Q804,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +328 tripletas (sujetos 150), offset 0
#    [trip] +288 tripletas (sujetos 300), offset 150
#    [trip] +251 tripletas (sujetos 429), offset 300
#    [trip] +203 tripletas (sujetos 515), offset 450
#    [trip] +197 tripletas (sujetos 610), offset 600
#    [trip] +291 tripletas (sujetos 737), offset 750
#    [trip] +301 tripletas (sujetos 887), offset 900
#    [trip] +126 tripletas (sujetos 937), offset 1050
#    [trip] +300 tripletas (sujetos 1082), offset 1200
#    [trip] +239 tripletas (sujetos 1211), offset 1350
#    [trip] +279 tripletas (sujetos 1355), offset 1500
#    [trip] +122 tripletas (sujetos 1418), offset 1650
#    [trip] +279 tripletas (sujetos 1568), offset 1800
#    [trip] +69 tripletas (sujetos 1608), offset 1950
#    [trip] +252 tripletas (sujetos 1743), offset 2100
#    [trip] +279 tripletas (sujetos 1891), offset 2250
#    [trip] +237 tripletas (sujetos 2027), offset 2400
#    [trip] +245 tripletas (sujetos 2165), offset 2550
#    [trip] +285 tripletas (sujetos 2315), offset 2700
#    [trip] +279 tripletas (sujetos 2461), offset 2850
#    [trip] +299 tripletas (sujetos 2605), offset 3000
#    [trip] +94 tripletas (sujetos 2663), offset 3150
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
# [WARN] HTTP 504. Reintentando en 1.7s (intento 2/6)…
# [WARN] HTTP 504. Reintentando en 3.6s (intento 3/6)…
#    [fin] no hay más páginas.
# ✔ (Q804,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 5243
# → (Q733,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +344 tripletas (sujetos 150), offset 0
#    [trip] +322 tripletas (sujetos 300), offset 150
#    [trip] +273 tripletas (sujetos 437), offset 300
#    [trip] +271 tripletas (sujetos 586), offset 450
#    [fin] no hay más páginas.
# ✔ (Q733,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 1210
# → (Q419,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +312 tripletas (sujetos 150), offset 0
#    [trip] +284 tripletas (sujetos 300), offset 150
#    [trip] +202 tripletas (sujetos 400), offset 300
#    [trip] +298 tripletas (sujetos 550), offset 450
#    [trip] +318 tripletas (sujetos 700), offset 600
#    [trip] +321 tripletas (sujetos 846), offset 750
#    [trip] +234 tripletas (sujetos 958), offset 900
#    [trip] +314 tripletas (sujetos 1108), offset 1050
#    [trip] +302 tripletas (sujetos 1258), offset 1200
#    [trip] +92 tripletas (sujetos 1304), offset 1350
#    [trip] +184 tripletas (sujetos 1396), offset 1500
#    [trip] +299 tripletas (sujetos 1545), offset 1650
#    [trip] +186 tripletas (sujetos 1637), offset 1800
#    [trip] +101 tripletas (sujetos 1687), offset 1950
#    [trip] +287 tripletas (sujetos 1829), offset 2100
#    [trip] +75 tripletas (sujetos 1866), offset 2250
#    [trip] +144 tripletas (sujetos 1938), offset 2400
#    [trip] +308 tripletas (sujetos 2088), offset 2550
#    [trip] +378 tripletas (sujetos 2238), offset 2700
#    [trip] +403 tripletas (sujetos 2388), offset 2850
#    [trip] +414 tripletas (sujetos 2516), offset 3000
#    [trip] +300 tripletas (sujetos 2666), offset 3150
#    [trip] +300 tripletas (sujetos 2816), offset 3300
#    [trip] +270 tripletas (sujetos 2951), offset 3450
#    [trip] +300 tripletas (sujetos 3101), offset 3600
#    [trip] +288 tripletas (sujetos 3245), offset 3750
#    [trip] +208 tripletas (sujetos 3349), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q419,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 7122
# → (Q786,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +298 tripletas (sujetos 150), offset 0
#    [trip] +237 tripletas (sujetos 300), offset 150
#    [trip] +198 tripletas (sujetos 450), offset 300
#    [trip] +211 tripletas (sujetos 600), offset 450
#    [trip] +218 tripletas (sujetos 750), offset 600
#    [trip] +194 tripletas (sujetos 893), offset 750
#    [trip] +110 tripletas (sujetos 968), offset 900
#    [trip] +114 tripletas (sujetos 1045), offset 1050
#    [trip] +222 tripletas (sujetos 1195), offset 1200
#    [trip] +208 tripletas (sujetos 1345), offset 1350
#    [trip] +123 tripletas (sujetos 1434), offset 1500
#    [skip] página offset 1650 ya cubierta por checkpoint
#    [trip] +199 tripletas (sujetos 1584), offset 1800
#    [trip] +187 tripletas (sujetos 1714), offset 1950
#    [skip] página offset 2100 ya cubierta por checkpoint
#    [trip] +49 tripletas (sujetos 1748), offset 2250
#    [trip] +53 tripletas (sujetos 1787), offset 2400
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
#    [trip] +20 tripletas (sujetos 1803), offset 2550
#    [trip] +208 tripletas (sujetos 1952), offset 2700
#    [trip] +72 tripletas (sujetos 2002), offset 2850
#    [trip] +231 tripletas (sujetos 2152), offset 3000
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
#    [trip] +221 tripletas (sujetos 2302), offset 3150
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
#    [trip] +164 tripletas (sujetos 2417), offset 3300
#    [trip] +175 tripletas (sujetos 2549), offset 3450
#    [trip] +222 tripletas (sujetos 2699), offset 3600
#    [trip] +67 tripletas (sujetos 2749), offset 3750
#    [trip] +218 tripletas (sujetos 2898), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q786,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 4219
# → (Q77,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +335 tripletas (sujetos 150), offset 0
#    [trip] +320 tripletas (sujetos 300), offset 150
#    [trip] +296 tripletas (sujetos 448), offset 300
#    [trip] +293 tripletas (sujetos 597), offset 450
#    [trip] +294 tripletas (sujetos 745), offset 600
#    [trip] +108 tripletas (sujetos 801), offset 750
#    [trip] +289 tripletas (sujetos 945), offset 900
#    [trip] +297 tripletas (sujetos 1095), offset 1050
# [WARN] HTTP 504. Reintentando en 1.0s (intento 1/6)…
#    [trip] +288 tripletas (sujetos 1238), offset 1200
# [WARN] HTTP 504. Reintentando en 1.3s (intento 1/6)…
#    [trip] +250 tripletas (sujetos 1385), offset 1350
#    [trip] +261 tripletas (sujetos 1535), offset 1500
#    [trip] +343 tripletas (sujetos 1685), offset 1650
#    [trip] +298 tripletas (sujetos 1829), offset 1800
#    [trip] +300 tripletas (sujetos 1979), offset 1950
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
#    [trip] +227 tripletas (sujetos 2099), offset 2100
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
#    [trip] +11 tripletas (sujetos 2105), offset 2250
# [WARN] HTTP 504. Reintentando en 1.2s (intento 1/6)…
#    [fin] no hay más páginas.
# ✔ (Q77,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 4210
# → (Q717,Q2221906) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +316 tripletas (sujetos 150), offset 0
#    [trip] +443 tripletas (sujetos 300), offset 150
#    [trip] +310 tripletas (sujetos 448), offset 300
#    [trip] +409 tripletas (sujetos 594), offset 450
#    [trip] +321 tripletas (sujetos 714), offset 600
#    [trip] +481 tripletas (sujetos 864), offset 750
#    [trip] +310 tripletas (sujetos 961), offset 900
#    [trip] +269 tripletas (sujetos 1043), offset 1050
#    [trip] +366 tripletas (sujetos 1160), offset 1200
#    [trip] +157 tripletas (sujetos 1210), offset 1350
#    [trip] +107 tripletas (sujetos 1255), offset 1500
#    [trip] +450 tripletas (sujetos 1392), offset 1650
#    [trip] +386 tripletas (sujetos 1496), offset 1800
#    [trip] +186 tripletas (sujetos 1602), offset 1950
#    [trip] +283 tripletas (sujetos 1752), offset 2100
#    [trip] +184 tripletas (sujetos 1852), offset 2250
#    [trip] +204 tripletas (sujetos 2002), offset 2400
#    [trip] +148 tripletas (sujetos 2107), offset 2550
#    [trip] +290 tripletas (sujetos 2257), offset 2700
#    [trip] +274 tripletas (sujetos 2407), offset 2850
#    [trip] +299 tripletas (sujetos 2557), offset 3000
#    [trip] +72 tripletas (sujetos 2594), offset 3150
#    [trip] +94 tripletas (sujetos 2641), offset 3300
#    [trip] +153 tripletas (sujetos 2718), offset 3450
#    [trip] +257 tripletas (sujetos 2857), offset 3600
#    [trip] +156 tripletas (sujetos 2937), offset 3750
#    [trip] +210 tripletas (sujetos 3077), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q717,Q2221906) streaming listo. Tripletas nuevas en esta corrida: 7135

# %%
salida = os.path.join(CHECKPOINT_DIR, "kg_sitios_interes_latam.json")
consolidate_triplets_to_graph_json(salida, title="Sitios de interés geográfico en LATAM", domain_tag="sitios_latam")
# Out:
# Consolidando 103493 tripletas…
# ✅ Guardado: C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios\kg_sitios_interes_latam.json (nodos 54227, aristas 103493)

# %%
plot_graph_from_json("GC_peliculas_latam.json", max_nodes=100)

# %% [markdown]
# ## Scrapping peliculas LATAM

# %%
# -*- coding: utf-8 -*-
import os, re, json, time, random, socket, glob
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# --- CONFIG PELÍCULAS ---
import os

# Carpeta separada para checkpoints de películas
CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_peliculas"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# Países LATAM (mismos de antes)
LATAM_COUNTRIES_QIDS = [
    "Q414","Q750","Q155","Q298","Q739","Q800","Q241","Q736","Q792","Q774",
    "Q783","Q96","Q811","Q804","Q733","Q419","Q786","Q77","Q717"
]

# Tipo: Película
TYPE_QIDS = ["Q11424"]     # film (incluiremos subclases con /wdt:P279*)

# Para películas el país es "país de origen"
PROP_COUNTRY = "P495"
# Tipo/instancia: se mantiene P31
PROP_TYPE    = "P31"

# Parámetros de robustez (ajústalos si hace falta)
PAGE_SIZE       = 150
PER_COMBO_MAX   = 4000
TRIPLET_BATCH   = 180
SLEEP_BETWEEN_PAGES = 0.25

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

# ========= UTILIDADES SPARQL ROBUSTO =========
def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try:
                s.setTimeout(timeout_s * 1000)
            except Exception:
                s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0:
                time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# ========= JSONL / OFFSET CHECKPOINT =========
def _items_path(cq, tq):     return os.path.join(CHECKPOINT_DIR, f"items_{cq}_{tq}.jsonl")
def _triplets_path(cq, tq):  return os.path.join(CHECKPOINT_DIR, f"triplets_{cq}_{tq}.jsonl")
def _offset_path(cq, tq):    return os.path.join(CHECKPOINT_DIR, f"offset_{cq}_{tq}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_jsonl(path):
    out=[]
    if not os.path.exists(path): return out
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line=line.strip()
            if not line: continue
            out.append(json.loads(line))
    return out

def _read_done_subjects(trip_path):
    done=set()
    if not os.path.exists(trip_path): return done
    with open(trip_path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(cq,tq):
    p=_offset_path(cq,tq)
    if not os.path.exists(p): return 0
    try:
        return int(open(p,"r").read().strip())
    except:
        return 0

def _write_offset(cq,tq,offset):
    with open(_offset_path(cq,tq),"w") as f:
        f.write(str(offset))

# ========= TRIPLETAS (igual “que antes”) =========
# Reemplaza (o extiende) tu whitelist para películas:
DEFAULT_PROP_WHITELIST = [
    "P31",    # instancia de
    "P136",   # género
    "P495",   # país de origen
    "P364",   # idioma original de la obra
    "P577",   # fecha de publicación/estreno
    "P57",    # director
    "P58",    # guionista
    "P161",   # reparto (cast member)
    "P162",   # productor
    "P272",   # productora
    "P344",   # director de fotografía
    "P915",   # locación de rodaje
    "P449",   # red original (para TV; por si cae alguna)
    "P2047",  # (ignorar si no aplica; puedes quitarla)
    # genéricas que ya usabas, por si suman señal:
    "P279","P361","P737","P739","P800"
]


def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or DEFAULT_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)

    # sin labels para items muy grandes sería más liviano, pero aquí sí los queremos (como antes)
    query = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(query)
    trip=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        p_iri  = b["p"]["value"]
        pid    = p_iri.split("/")[-1]
        pid    = pid.split(":")[-1] if ":" in pid else pid
        p_lab  = b.get("propLabel",{}).get("value", pid)
        o_val  = b["o"]["value"]
        o_lab  = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        trip.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return trip

# ========= PÁGINAS DE ÍTEMS (SOLO IDs) =========
def fetch_items_page(country_qid: str, type_qid: str, offset: int, limit: int,
                     prop_country: str=PROP_COUNTRY, prop_type: str=PROP_TYPE) -> List[str]:
    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{country_qid} }}
      # ?item wdt:{prop_country} ?country .
      # ?item wdt:{prop_type}/wdt:P279* wd:{type_qid} .
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]

# ========= STREAMING POR (PAÍS, TIPO) CON CHECKPOINT REAL =========
def stream_country_type(cq: str, tq: str,
                        per_combo_max: int=PER_COMBO_MAX,
                        page_size: int=PAGE_SIZE,
                        triplet_batch: int=TRIPLET_BATCH):
    off = _read_offset(cq,tq)
    items_file = _items_path(cq,tq)
    trips_file = _triplets_path(cq,tq)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ ({cq},{tq}) reanudando desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page(cq, tq, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        # guarda la página de items (por trazabilidad) — opcional
        _append_jsonl(items_file, [{"qid": q} for q in ids])
        # filtra los que faltan tripletas
        pend = [q for q in ids if q not in done]
        if pend:
            # por lotes de tripletas
            for i in range(0, len(pend), triplet_batch):
                chunk = pend[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk)
                    if trip:
                        _append_jsonl(trips_file, trip)      # ← GUARDA TRIPLETAS INMEDIATO
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch de tripletas en offset {off}: {e}; sigo…")
                    time.sleep(1.0)
        else:
            print(f"   [skip] página offset {off} ya cubierta por checkpoint")

        off += page_size
        _write_offset(cq,tq,off)            # ← ACTUALIZA OFFSET TRAS CADA PÁGINA
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_combo_max:
            print(f"   [cut] alcance per_combo_max={per_combo_max}"); break

    print(f"✔ ({cq},{tq}) streaming listo. Tripletas nuevas en esta corrida: {total_new}")

# ========= CONSOLIDACIÓN A KG (nodes/edges) =========
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}
    edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}

    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True)
            tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt, "property_pid": t["property_pid"], "property_label": t["property_label"]})

    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_path: str, title: str, domain_tag: str):
    # Lee TODOS los triplets_*.jsonl del CHECKPOINT_DIR
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    with open(output_path,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {output_path} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

# %%
for cq in LATAM_COUNTRIES_QIDS:
    for tq in TYPE_QIDS:  # ["Q11424"]
        stream_country_type(
            cq, tq,
            per_combo_max=PER_COMBO_MAX,
            page_size=PAGE_SIZE,
            triplet_batch=TRIPLET_BATCH
        )
# Out:
# → (Q414,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +3446 tripletas (sujetos 150), offset 0
#    [trip] +3225 tripletas (sujetos 299), offset 150
#    [trip] +2854 tripletas (sujetos 437), offset 300
#    [trip] +2326 tripletas (sujetos 547), offset 450
#    [trip] +2543 tripletas (sujetos 677), offset 600
#    [trip] +1988 tripletas (sujetos 782), offset 750
#    [trip] +2842 tripletas (sujetos 930), offset 900
#    [trip] +1824 tripletas (sujetos 1028), offset 1050
#    [trip] +2800 tripletas (sujetos 1178), offset 1200
#    [trip] +909 tripletas (sujetos 1229), offset 1350
#    [trip] +2963 tripletas (sujetos 1379), offset 1500
#    [trip] +2813 tripletas (sujetos 1519), offset 1650
#    [trip] +2574 tripletas (sujetos 1648), offset 1800
#    [trip] +2139 tripletas (sujetos 1757), offset 1950
#    [trip] +2637 tripletas (sujetos 1905), offset 2100
#    [trip] +2475 tripletas (sujetos 2040), offset 2250
#    [trip] +2519 tripletas (sujetos 2189), offset 2400
#    [trip] +2342 tripletas (sujetos 2332), offset 2550
#    [trip] +2438 tripletas (sujetos 2477), offset 2700
#    [trip] +1559 tripletas (sujetos 2614), offset 2850
#    [trip] +1755 tripletas (sujetos 2764), offset 3000
#    [trip] +1560 tripletas (sujetos 2905), offset 3150
#    [trip] +1468 tripletas (sujetos 3055), offset 3300
#    [trip] +1181 tripletas (sujetos 3203), offset 3450
#    [trip] +1240 tripletas (sujetos 3339), offset 3600
#    [trip] +1744 tripletas (sujetos 3484), offset 3750
#    [trip] +1606 tripletas (sujetos 3622), offset 3900
#    [cut] alcance per_combo_max=4000
# ✔ (Q414,Q11424) streaming listo. Tripletas nuevas en esta corrida: 59770
# → (Q750,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +782 tripletas (sujetos 91), offset 0
#    [fin] no hay más páginas.
# ✔ (Q750,Q11424) streaming listo. Tripletas nuevas en esta corrida: 782
# → (Q155,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +2532 tripletas (sujetos 150), offset 0
#    [trip] +1782 tripletas (sujetos 297), offset 150
#    [trip] +1548 tripletas (sujetos 444), offset 300
#    [trip] +1207 tripletas (sujetos 594), offset 450
#    [trip] +1138 tripletas (sujetos 744), offset 600
#    [trip] +901 tripletas (sujetos 847), offset 750
#    [trip] +412 tripletas (sujetos 896), offset 900
#    [trip] +583 tripletas (sujetos 968), offset 1050
#    [trip] +1180 tripletas (sujetos 1111), offset 1200
#    [trip] +572 tripletas (sujetos 1180), offset 1350
#    [trip] +1282 tripletas (sujetos 1328), offset 1500
#    [trip] +1149 tripletas (sujetos 1474), offset 1650
#    [trip] +995 tripletas (sujetos 1607), offset 1800
#    [trip] +1048 tripletas (sujetos 1757), offset 1950
#    [trip] +998 tripletas (sujetos 1896), offset 2100
#    [trip] +1048 tripletas (sujetos 2045), offset 2250
#    [trip] +1305 tripletas (sujetos 2190), offset 2400
#    [trip] +1157 tripletas (sujetos 2335), offset 2550
#    [trip] +999 tripletas (sujetos 2467), offset 2700
#    [trip] +1293 tripletas (sujetos 2615), offset 2850
#    [trip] +713 tripletas (sujetos 2716), offset 3000
#    [fin] no hay más páginas.
# ✔ (Q155,Q11424) streaming listo. Tripletas nuevas en esta corrida: 23842
# → (Q298,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1865 tripletas (sujetos 150), offset 0
#    [trip] +1289 tripletas (sujetos 284), offset 150
#    [trip] +1730 tripletas (sujetos 434), offset 300
#    [trip] +1431 tripletas (sujetos 582), offset 450
#    [trip] +70 tripletas (sujetos 591), offset 600
#    [fin] no hay más páginas.
# ✔ (Q298,Q11424) streaming listo. Tripletas nuevas en esta corrida: 6385
# → (Q739,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1633 tripletas (sujetos 150), offset 0
#    [trip] +1287 tripletas (sujetos 300), offset 150
#    [trip] +1232 tripletas (sujetos 449), offset 300
#    [trip] +1271 tripletas (sujetos 599), offset 450
#    [trip] +124 tripletas (sujetos 614), offset 600
#    [fin] no hay más páginas.
# ✔ (Q739,Q11424) streaming listo. Tripletas nuevas en esta corrida: 5547
# → (Q800,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +453 tripletas (sujetos 51), offset 0
#    [fin] no hay más páginas.
# ✔ (Q800,Q11424) streaming listo. Tripletas nuevas en esta corrida: 453
# → (Q241,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1758 tripletas (sujetos 150), offset 0
#    [trip] +902 tripletas (sujetos 237), offset 150
#    [fin] no hay más páginas.
# ✔ (Q241,Q11424) streaming listo. Tripletas nuevas en esta corrida: 2660
# → (Q736,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +812 tripletas (sujetos 93), offset 0
#    [fin] no hay más páginas.
# ✔ (Q736,Q11424) streaming listo. Tripletas nuevas en esta corrida: 812
# → (Q792,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +189 tripletas (sujetos 20), offset 0
#    [fin] no hay más páginas.
# ✔ (Q792,Q11424) streaming listo. Tripletas nuevas en esta corrida: 189
# → (Q774,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +368 tripletas (sujetos 39), offset 0
#    [fin] no hay más páginas.
# ✔ (Q774,Q11424) streaming listo. Tripletas nuevas en esta corrida: 368
# → (Q783,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +160 tripletas (sujetos 20), offset 0
#    [fin] no hay más páginas.
# ✔ (Q783,Q11424) streaming listo. Tripletas nuevas en esta corrida: 160
# → (Q96,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +3301 tripletas (sujetos 150), offset 0
#    [trip] +2382 tripletas (sujetos 294), offset 150
#    [trip] +1991 tripletas (sujetos 442), offset 300
#    [trip] +1626 tripletas (sujetos 591), offset 450
#    [trip] +1457 tripletas (sujetos 710), offset 600
#    [trip] +1288 tripletas (sujetos 812), offset 750
#    [trip] +1176 tripletas (sujetos 918), offset 900
#    [trip] +1088 tripletas (sujetos 1022), offset 1050
#    [trip] +1583 tripletas (sujetos 1152), offset 1200
#    [trip] +1986 tripletas (sujetos 1300), offset 1350
#    [trip] +1600 tripletas (sujetos 1424), offset 1500
#    [trip] +1926 tripletas (sujetos 1574), offset 1650
#    [trip] +1550 tripletas (sujetos 1713), offset 1800
#    [trip] +1236 tripletas (sujetos 1817), offset 1950
#    [trip] +1515 tripletas (sujetos 1943), offset 2100
#    [trip] +1662 tripletas (sujetos 2091), offset 2250
#    [trip] +1572 tripletas (sujetos 2234), offset 2400
#    [trip] +1875 tripletas (sujetos 2381), offset 2550
#    [trip] +1594 tripletas (sujetos 2531), offset 2700
#    [trip] +1339 tripletas (sujetos 2679), offset 2850
#    [trip] +1192 tripletas (sujetos 2815), offset 3000
#    [trip] +730 tripletas (sujetos 2896), offset 3150
#    [fin] no hay más páginas.
# ✔ (Q96,Q11424) streaming listo. Tripletas nuevas en esta corrida: 35669
# → (Q811,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +214 tripletas (sujetos 19), offset 0
#    [fin] no hay más páginas.
# ✔ (Q811,Q11424) streaming listo. Tripletas nuevas en esta corrida: 214
# → (Q804,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +480 tripletas (sujetos 35), offset 0
#    [fin] no hay más páginas.
# ✔ (Q804,Q11424) streaming listo. Tripletas nuevas en esta corrida: 480
# → (Q733,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +433 tripletas (sujetos 50), offset 0
#    [fin] no hay más páginas.
# ✔ (Q733,Q11424) streaming listo. Tripletas nuevas en esta corrida: 433
# → (Q419,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1791 tripletas (sujetos 150), offset 0
#    [trip] +1397 tripletas (sujetos 299), offset 150
#    [trip] +978 tripletas (sujetos 436), offset 300
#    [trip] +433 tripletas (sujetos 503), offset 450
#    [trip] +747 tripletas (sujetos 622), offset 600
#    [trip] +710 tripletas (sujetos 732), offset 750
#    [trip] +1015 tripletas (sujetos 875), offset 900
#    [trip] +917 tripletas (sujetos 994), offset 1050
#    [fin] no hay más páginas.
# ✔ (Q419,Q11424) streaming listo. Tripletas nuevas en esta corrida: 7988
# → (Q786,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1094 tripletas (sujetos 115), offset 0
#    [fin] no hay más páginas.
# ✔ (Q786,Q11424) streaming listo. Tripletas nuevas en esta corrida: 1094
# → (Q77,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1496 tripletas (sujetos 150), offset 0
#    [trip] +756 tripletas (sujetos 229), offset 150
#    [fin] no hay más páginas.
# ✔ (Q77,Q11424) streaming listo. Tripletas nuevas en esta corrida: 2252
# → (Q717,Q11424) reanudando desde offset 0, sujetos ya con tripletas: 0
#    [trip] +1573 tripletas (sujetos 150), offset 0
#    [trip] +692 tripletas (sujetos 244), offset 150
#    [fin] no hay más páginas.
# ✔ (Q717,Q11424) streaming listo. Tripletas nuevas en esta corrida: 2265

# %%
salida = os.path.join(CHECKPOINT_DIR, "kg_peliculas_latam.json")
consolidate_triplets_to_graph_json(salida, title="Películas en LATAM", domain_tag="peliculas_latam")
# Out:
# Consolidando 151363 tripletas…
# ✅ Guardado: C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_peliculas\kg_peliculas_latam.json (nodos 34580, aristas 151363)

# %% [markdown]
# ## Scrapping de danzas y bailes

# %%
# === CONFIG para la VÍA B (criterios por género/forma + dance music) ===
import os, json, time, random, socket, glob, re
from urllib.error import HTTPError, URLError
from typing import List, Dict
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# Carpeta de checkpoints para danzas por criterios (separada de las otras)
CHECKPOINT_DIR = r"C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_danzas_criterios"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# --- CONFIG DANZAS por PAÍS ---
import os, json, time, random, socket, glob, re
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

CHECKPOINT_DIR = r"C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_danzas_por_pais"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

LATAM_COUNTRIES_QIDS = [
    "Q414","Q750","Q155","Q298","Q739","Q800","Q241","Q736","Q792","Q774",
    "Q783","Q96","Q811","Q804","Q733","Q419","Q786","Q77","Q717"
]

# Criterios “bailables”:
INSTANCE_TYPES_QIDS = ["Q188451", "Q3046146"]   # music genre, musical form
SUBCLASS_ROOTS_QIDS = ["Q180018", "Q18345375", "Q18345375"]               # dance music

# País para danzas: país de ORIGEN
PROP_COUNTRY = "P495"
PAGE_SIZE = 150
PER_COUNTRY_MAX = 4000
TRIPLET_BATCH = 180
SLEEP_BETWEEN_PAGES = 0.25


WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# Helpers de checkpoint
def _items_path():    return os.path.join(CHECKPOINT_DIR, f"items_criterios.jsonl")
def _triplets_path(): return os.path.join(CHECKPOINT_DIR, f"triplets_criterios.jsonl")
def _offset_path():   return os.path.join(CHECKPOINT_DIR, f"offset_criterios.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(trip_path):
    done=set()
    if not os.path.exists(trip_path): return done
    with open(trip_path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset():
    p=_offset_path()
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(offset: int):
    with open(_offset_path(),"w") as f: f.write(str(offset))

# Tripletas “como antes” (puedes ajustar whitelist si quieres más/menos aristas)
DANCE_PROP_WHITELIST = [
    "P31","P279","P361","P495","P17","P136","P131"
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or DANCE_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)

    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    T=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid    = b["p"]["value"].split("/")[-1]
        pid    = pid.split(":")[-1] if ":" in pid else pid
        p_lab  = b.get("propLabel",{}).get("value", pid)
        o_val  = b["o"]["value"]
        o_lab  = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        T.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return T

# %%
def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

def _items_path(cq):    return os.path.join(CHECKPOINT_DIR, f"items_{cq}.jsonl")
def _triplets_path(cq): return os.path.join(CHECKPOINT_DIR, f"triplets_{cq}.jsonl")
def _offset_path(cq):   return os.path.join(CHECKPOINT_DIR, f"offset_{cq}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(cq):
    p=_offset_path(cq)
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(cq,off):
    with open(_offset_path(cq),"w") as f: f.write(str(off))

# Propiedades útiles para danzas/bailes
DANCE_PROP_WHITELIST = [
    "P31","P279","P361","P495","P17","P136","P131"
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or DANCE_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)
    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    out=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid = b["p"]["value"].split("/")[-1]
        pid = pid.split(":")[-1] if ":" in pid else pid
        p_lab = b.get("propLabel",{}).get("value", pid)
        o_val = b["o"]["value"]
        o_lab = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        out.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return out

def fetch_items_page_by_country(cq: str, offset: int, limit: int) -> List[str]:
    """
    Ítems que cumplen:
      - instancia de (music genre | musical form) (con subclases)
      - subclase de dance music (con jerarquía)
      - país de origen = cq  (P495)
    """
    inst_vals = " ".join(f"wd:{q}" for q in INSTANCE_TYPES_QIDS)
    root_vals = " ".join(f"wd:{q}" for q in SUBCLASS_ROOTS_QIDS)
    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?itype {{ {inst_vals} }}
      VALUES ?root  {{ {root_vals} }}
      VALUES ?country {{ wd:{cq} }}

      # ?item wdt:P31/wdt:P279* ?itype .
      # ?item wdt:P279* ?root .
      # ?item wdt:{PROP_COUNTRY} ?country .
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]

def stream_country(cq: str,
                   per_country_max: int=PER_COUNTRY_MAX,
                   page_size: int=PAGE_SIZE,
                   triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path(cq)
    trips_file = _triplets_path(cq)
    off = _read_offset(cq)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ Danzas por país {cq} desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page_by_country(cq, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        _append_jsonl(items_file, [{"qid": q} for q in ids])  # trazabilidad

        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk, prop_whitelist=DANCE_PROP_WHITELIST)
                    if trip:
                        _append_jsonl(trips_file, trip)    # ← checkpoint inmediato
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch en offset {off}: {e}; sigo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(cq, off)                      # ← guardo offset
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_country_max:
            print(f"   [cut] per_country_max={per_country_max}"); break

    print(f"✔ País {cq} listo. Tripletas nuevas: {total_new}")

# %%
for cq in LATAM_COUNTRIES_QIDS:
    stream_country(cq)
# Out:
# → Danzas por país Q414 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +130 tripletas (sujetos 25), offset 0
#    [fin] no hay más páginas.
# ✔ País Q414 listo. Tripletas nuevas: 130
# → Danzas por país Q750 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +81 tripletas (sujetos 12), offset 0
#    [fin] no hay más páginas.
# ✔ País Q750 listo. Tripletas nuevas: 81
# → Danzas por país Q155 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +393 tripletas (sujetos 100), offset 0
#    [fin] no hay más páginas.
# ✔ País Q155 listo. Tripletas nuevas: 393
# → Danzas por país Q298 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +89 tripletas (sujetos 19), offset 0
#    [fin] no hay más páginas.
# ✔ País Q298 listo. Tripletas nuevas: 89
# → Danzas por país Q739 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +91 tripletas (sujetos 19), offset 0
#    [fin] no hay más páginas.
# ✔ País Q739 listo. Tripletas nuevas: 91
# → Danzas por país Q800 desde offset 0, sujetos ya con tripletas: 0
#    [fin] no hay más páginas.
# ✔ País Q800 listo. Tripletas nuevas: 0
# → Danzas por país Q241 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +94 tripletas (sujetos 23), offset 0
#    [fin] no hay más páginas.
# ✔ País Q241 listo. Tripletas nuevas: 94
# → Danzas por país Q736 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +10 tripletas (sujetos 2), offset 0
#    [fin] no hay más páginas.
# ✔ País Q736 listo. Tripletas nuevas: 10
# → Danzas por país Q792 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +8 tripletas (sujetos 2), offset 0
#    [fin] no hay más páginas.
# ✔ País Q792 listo. Tripletas nuevas: 8
# → Danzas por país Q774 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +5 tripletas (sujetos 1), offset 0
#    [fin] no hay más páginas.
# ✔ País Q774 listo. Tripletas nuevas: 5
# → Danzas por país Q783 desde offset 0, sujetos ya con tripletas: 0
#    [fin] no hay más páginas.
# ✔ País Q783 listo. Tripletas nuevas: 0
# → Danzas por país Q96 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +200 tripletas (sujetos 47), offset 0
#    [fin] no hay más páginas.
# ✔ País Q96 listo. Tripletas nuevas: 200
# → Danzas por país Q811 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +4 tripletas (sujetos 1), offset 0
#    [fin] no hay más páginas.
# ✔ País Q811 listo. Tripletas nuevas: 4
# → Danzas por país Q804 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +16 tripletas (sujetos 3), offset 0
#    [fin] no hay más páginas.
# ✔ País Q804 listo. Tripletas nuevas: 16
# → Danzas por país Q733 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +8 tripletas (sujetos 2), offset 0
#    [fin] no hay más páginas.
# ✔ País Q733 listo. Tripletas nuevas: 8
# → Danzas por país Q419 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +131 tripletas (sujetos 26), offset 0
#    [fin] no hay más páginas.
# ✔ País Q419 listo. Tripletas nuevas: 131
# → Danzas por país Q786 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +17 tripletas (sujetos 3), offset 0
#    [fin] no hay más páginas.
# ✔ País Q786 listo. Tripletas nuevas: 17
# → Danzas por país Q77 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +37 tripletas (sujetos 6), offset 0
#    [fin] no hay más páginas.
# ✔ País Q77 listo. Tripletas nuevas: 37
# → Danzas por país Q717 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +87 tripletas (sujetos 18), offset 0
#    [fin] no hay más páginas.
# ✔ País Q717 listo. Tripletas nuevas: 87

# %%
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}; edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}
    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True); tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt,
                      "property_pid": t["property_pid"], "property_label": t["property_label"]})
    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_filename: str, title: str, domain_tag: str):
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    out = os.path.join(CHECKPOINT_DIR, output_filename)
    with open(out,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {out} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

# Ejecuta consolidación
consolidate_triplets_to_graph_json("kg_danzas_por_pais.json",
                                   title="Danzas y bailes por país de origen (LATAM)",
                                   domain_tag="danzas_por_pais")
# Out:
# Consolidando 1401 tripletas…
# ✅ Guardado: C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_danzas_por_pais\kg_danzas_por_pais.json (nodos 451, aristas 1401)

# %% [markdown]
# ## Scrapping de grupos indígenas de LATAM

# %%
# --- CONFIG INDÍGENAS POR PAÍS ---
import os, json, time, random, socket, glob, re
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_indigenas"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

LATAM_COUNTRIES_QIDS = [
    "Q414","Q750","Q155","Q298","Q739","Q800","Q241","Q736","Q792","Q774",
    "Q783","Q96","Q811","Q804","Q733","Q419","Q786","Q77","Q717"
]

# Raíces de tipo:
ETHNIC_GROUP_QID = "Q41710"       # ethnic group (universal y muy usado)
INDIGENOUS_ROOTS_QIDS = []        # <- opcional: pon aquí QIDs de "indigenous people" si quieres exigirlo (p.ej. ["QXXXX"])

# Propiedades-país que usamos para vincular el grupo a un país
PROP_COUNTRY_DIRECT   = "P17"     # country (a veces usado en grupos)
PROP_INDEG_TO         = "P2341"   # indigenous to / native to
# Vía territorial: P131 (entidad territorial) y desde ahí llegamos al país por P17
PROP_ADMIN_ENTITY     = "P131"

# Robustez
PAGE_SIZE           = 150
PER_COUNTRY_MAX     = 4000
TRIPLET_BATCH       = 180
SLEEP_BETWEEN_PAGES = 0.25

# SPARQL
WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# Paths de checkpoint
def _items_path(cq):    return os.path.join(CHECKPOINT_DIR, f"items_{cq}.jsonl")
def _triplets_path(cq): return os.path.join(CHECKPOINT_DIR, f"triplets_{cq}.jsonl")
def _offset_path(cq):   return os.path.join(CHECKPOINT_DIR, f"offset_{cq}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(cq):
    p=_offset_path(cq)
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(cq,off):
    with open(_offset_path(cq),"w") as f: f.write(str(off))
# Propiedades a extraer para el grafo
INDIGENOUS_PROP_WHITELIST = [
    "P31",    # instancia de
    "P279",   # subclase de
    "P361",   # parte de
    "P17",    # país (si lo tienen)
    "P2341",  # indigenous to / native to
    "P131",   # entidad territorial administrativa
    "P495",   # país de origen (a veces aparece)
    "P1705",  # nombre nativo
    "P37",    # idioma oficial/usado (a veces en items de grupo)
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or INDIGENOUS_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)
    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    out=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid = b["p"]["value"].split("/")[-1]
        pid = pid.split(":")[-1] if ":" in pid else pid
        p_lab = b.get("propLabel",{}).get("value", pid)
        o_val = b["o"]["value"]
        o_lab = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        out.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return out

def fetch_items_page_by_country(cq: str, offset: int, limit: int) -> List[str]:
    """
    Trae ítems que sean:
       (A) ethnic group  Y  vinculados a ?country por (P2341 | P17 | P131→P17)
    o  (B) (opcional) instance/subclass of some INDIGENOUS_ROOTS_QIDS  Y  mismo vínculo a ?country.
    """
    indigenous_block = ""
    if INDIGENOUS_ROOTS_QIDS:
        roots = " ".join(f"wd:{q}" for q in INDIGENOUS_ROOTS_QIDS)
        indigenous_block = f"""
        UNION {{
          VALUES ?iroot {{ {roots} }}
          # ?item wdt:P31/wdt:P279* ?iroot .
          # ?item (wdt:{PROP_INDEG_TO}|wdt:{PROP_COUNTRY_DIRECT}|wdt:{PROP_ADMIN_ENTITY}/wdt:{PROP_COUNTRY_DIRECT}) ?country .
        }}
        """

    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{cq} }}

      {{
        # ?item wdt:P31/wdt:P279* wd:{ETHNIC_GROUP_QID} .
        # ?item (wdt:{PROP_INDEG_TO}|wdt:{PROP_COUNTRY_DIRECT}|wdt:{PROP_ADMIN_ENTITY}/wdt:{PROP_COUNTRY_DIRECT}) ?country .
      }}
      {indigenous_block}
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
def stream_country(cq: str,
                   per_country_max: int=PER_COUNTRY_MAX,
                   page_size: int=PAGE_SIZE,
                   triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path(cq)
    trips_file = _triplets_path(cq)
    off = _read_offset(cq)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ Pueblos indígenas en {cq} desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page_by_country(cq, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        _append_jsonl(items_file, [{"qid": q} for q in ids])  # trazabilidad

        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk, prop_whitelist=INDIGENOUS_PROP_WHITELIST)
                    if trip:
                        _append_jsonl(trips_file, trip)    # ← checkpoint inmediato
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch en offset {off}: {e}; sigo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(cq, off)                      # ← guardo offset
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_country_max:
            print(f"   [cut] per_country_max={per_country_max}"); break

    print(f"✔ País {cq} listo. Tripletas nuevas: {total_new}")

# %%
for cq in LATAM_COUNTRIES_QIDS:
    stream_country(cq)
# Out:
# → Pueblos indígenas en Q414 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +317 tripletas (sujetos 57), offset 0
#    [fin] no hay más páginas.
# ✔ País Q414 listo. Tripletas nuevas: 317
# → Pueblos indígenas en Q750 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +176 tripletas (sujetos 47), offset 0
#    [fin] no hay más páginas.
# ✔ País Q750 listo. Tripletas nuevas: 176
# → Pueblos indígenas en Q155 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +501 tripletas (sujetos 150), offset 0
#    [trip] +702 tripletas (sujetos 297), offset 150
#    [trip] +300 tripletas (sujetos 372), offset 300
#    [fin] no hay más páginas.
# ✔ País Q155 listo. Tripletas nuevas: 1503
# → Pueblos indígenas en Q298 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +166 tripletas (sujetos 42), offset 0
#    [fin] no hay más páginas.
# ✔ País Q298 listo. Tripletas nuevas: 166
# → Pueblos indígenas en Q739 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +380 tripletas (sujetos 92), offset 0
#    [fin] no hay más páginas.
# ✔ País Q739 listo. Tripletas nuevas: 380
# → Pueblos indígenas en Q800 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +110 tripletas (sujetos 34), offset 0
#    [fin] no hay más páginas.
# ✔ País Q800 listo. Tripletas nuevas: 110
# → Pueblos indígenas en Q241 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +24 tripletas (sujetos 7), offset 0
#    [fin] no hay más páginas.
# ✔ País Q241 listo. Tripletas nuevas: 24
# → Pueblos indígenas en Q736 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +139 tripletas (sujetos 31), offset 0
#    [fin] no hay más páginas.
# ✔ País Q736 listo. Tripletas nuevas: 139
# → Pueblos indígenas en Q792 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +13 tripletas (sujetos 3), offset 0
#    [fin] no hay más páginas.
# ✔ País Q792 listo. Tripletas nuevas: 13
# → Pueblos indígenas en Q774 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +74 tripletas (sujetos 20), offset 0
#    [fin] no hay más páginas.
# ✔ País Q774 listo. Tripletas nuevas: 74
# → Pueblos indígenas en Q783 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +41 tripletas (sujetos 10), offset 0
#    [fin] no hay más páginas.
# ✔ País Q783 listo. Tripletas nuevas: 41
# → Pueblos indígenas en Q96 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +248 tripletas (sujetos 67), offset 0
#    [fin] no hay más páginas.
# ✔ País Q96 listo. Tripletas nuevas: 248
# → Pueblos indígenas en Q811 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +19 tripletas (sujetos 3), offset 0
#    [fin] no hay más páginas.
# ✔ País Q811 listo. Tripletas nuevas: 19
# → Pueblos indígenas en Q804 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +23 tripletas (sujetos 7), offset 0
#    [fin] no hay más páginas.
# ✔ País Q804 listo. Tripletas nuevas: 23
# → Pueblos indígenas en Q733 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +97 tripletas (sujetos 19), offset 0
#    [fin] no hay más páginas.
# ✔ País Q733 listo. Tripletas nuevas: 97
# → Pueblos indígenas en Q419 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +319 tripletas (sujetos 85), offset 0
#    [fin] no hay más páginas.
# ✔ País Q419 listo. Tripletas nuevas: 319
# → Pueblos indígenas en Q786 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +22 tripletas (sujetos 5), offset 0
#    [fin] no hay más páginas.
# ✔ País Q786 listo. Tripletas nuevas: 22
# → Pueblos indígenas en Q77 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +130 tripletas (sujetos 22), offset 0
#    [fin] no hay más páginas.
# ✔ País Q77 listo. Tripletas nuevas: 130
# → Pueblos indígenas en Q717 desde offset 0, sujetos ya con tripletas: 0
#    [trip] +278 tripletas (sujetos 67), offset 0
#    [fin] no hay más páginas.
# ✔ País Q717 listo. Tripletas nuevas: 278

# %%
# Consolidar a un KG único
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}; edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}
    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True); tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt,
                      "property_pid": t["property_pid"], "property_label": t["property_label"]})
    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_filename: str, title: str, domain_tag: str):
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    out = os.path.join(CHECKPOINT_DIR, output_filename)
    with open(out,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {out} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

consolidate_triplets_to_graph_json("kg_pueblos_indigenas_latam.json",
                                   title="Pueblos indígenas por país (Latinoamérica)",
                                   domain_tag="indigenas_latam")
# Out:
# Consolidando 4079 tripletas…
# ✅ Guardado: C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_indigenas\kg_pueblos_indigenas_latam.json (nodos 1453, aristas 4079)

# %% [markdown]
# ## Scrappeo EEUU

# %% [markdown]
# ### Pintores

# %%
# --- CONFIG PINTORXS USA ---
import os, json, time, random, socket, glob, re
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# Carpeta de checkpoints para este dominio
CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_pintores_us"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# País objetivo: Estados Unidos
COUNTRY_QID = "Q30"          # United States of America

# Raíz de ocupación: painter
OCCUPATION_ROOT_QID = "Q1028181"  # painter

# Robustez
PAGE_SIZE           = 150     # ítems por página
PER_COUNTRY_MAX     = 12000   # tope de ítems a traer (ajústalo si quieres)
TRIPLET_BATCH       = 180     # sujetos por lote al pedir tripletas
SLEEP_BETWEEN_PAGES = 0.25    # cortesía para el endpoint

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"
def _sparql(query: str, throttle_s: float = 0.25, max_retries: int = 6, base_sleep: float = 0.8, timeout_s: int = 60):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (academic)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
                print(f"[WARN] HTTP {e.code}. Reintentando en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0,0.5)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s (intento {attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

def _items_path():    return os.path.join(CHECKPOINT_DIR, f"items_{COUNTRY_QID}.jsonl")
def _triplets_path(): return os.path.join(CHECKPOINT_DIR, f"triplets_{COUNTRY_QID}.jsonl")
def _offset_path():   return os.path.join(CHECKPOINT_DIR, f"offset_{COUNTRY_QID}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset():
    p=_offset_path()
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(off: int):
    with open(_offset_path(),"w") as f: f.write(str(off))
# Propiedades útiles para humanos/artistas
PERSON_PROP_WHITELIST = [
    "P31",   # instancia de
    "P106",  # ocupación
    "P27",   # país de ciudadanía
    "P19",   # lugar de nacimiento
    "P20",   # lugar de fallecimiento
    "P69",   # educado en
    "P166",  # premio
    "P737",  # influenciado por
    "P135",  # movimiento
    "P800",  # obra destacada
    "P131",  # ubicado en entidad territorial
    "P136",  # género/estilo
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or PERSON_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p if p.startswith('P') else p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)

    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    out=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid = b["p"]["value"].split("/")[-1]
        pid = pid.split(":")[-1] if ":" in pid else pid
        p_lab = b.get("propLabel",{}).get("value", pid)
        o_val = b["o"]["value"]
        o_lab = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        out.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return out

def fetch_items_page(offset: int, limit: int) -> List[str]:
    """
    Humanxs (Q5) con ciudadanía USA (P27 = Q30) y ocupación 'painter' (incluye sub-ocupaciones).
    """
    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{COUNTRY_QID} }}
      # ?item wdt:P31 wd:Q5 .                          # humano
      # ?item wdt:P27 ?country .                       # ciudadanía USA
      # ?item wdt:P106 ?occ .                          # ocupación
      # ?occ  wdt:P279* wd:{OCCUPATION_ROOT_QID} .     # occ ⊑ painter
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
def stream_us_painters(per_country_max: int=PER_COUNTRY_MAX,
                       page_size: int=PAGE_SIZE,
                       triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path()
    trips_file = _triplets_path()
    off = _read_offset()
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ Pintores/as de USA desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page(offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        # guarda página de items (trazabilidad)
        _append_jsonl(items_file, [{"qid": q} for q in ids])

        # procesa solo los faltantes (checkpoint)
        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk, prop_whitelist=PERSON_PROP_WHITELIST)
                    if trip:
                        _append_jsonl(trips_file, trip)     # ← GUARDA YA
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch en offset {off}: {e}; sigo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(off)                                 # ← checkpoint de offset
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_country_max:
            print(f"   [cut] per_country_max={per_country_max}"); break

    print(f"✔ USA listo. Tripletas nuevas: {total_new}")

# %%
stream_us_painters()
# Out:
# → Pintores/as de USA desde offset 0, sujetos ya con tripletas: 0
#    [trip] +2693 tripletas (sujetos 150), offset 0
#    [trip] +930 tripletas (sujetos 229), offset 150
#    [trip] +1718 tripletas (sujetos 379), offset 300
#    [trip] +1516 tripletas (sujetos 520), offset 450
#    [trip] +1295 tripletas (sujetos 621), offset 600
#    [trip] +1207 tripletas (sujetos 737), offset 750
#    [trip] +1212 tripletas (sujetos 863), offset 900
#    [trip] +1119 tripletas (sujetos 996), offset 1050
#    [trip] +1264 tripletas (sujetos 1140), offset 1200
#    [trip] +1037 tripletas (sujetos 1257), offset 1350
#    [trip] +1168 tripletas (sujetos 1394), offset 1500
#    [trip] +1268 tripletas (sujetos 1544), offset 1650
#    [trip] +844 tripletas (sujetos 1662), offset 1800
#    [trip] +1116 tripletas (sujetos 1812), offset 1950
#    [trip] +915 tripletas (sujetos 1947), offset 2100
#    [trip] +1083 tripletas (sujetos 2097), offset 2250
#    [trip] +196 tripletas (sujetos 2130), offset 2400
#    [trip] +449 tripletas (sujetos 2196), offset 2550
#    [trip] +800 tripletas (sujetos 2324), offset 2700
#    [trip] +702 tripletas (sujetos 2433), offset 2850
#    [trip] +941 tripletas (sujetos 2571), offset 3000
#    [trip] +782 tripletas (sujetos 2686), offset 3150
#    [trip] +809 tripletas (sujetos 2812), offset 3300
#    [trip] +694 tripletas (sujetos 2912), offset 3450
#    [trip] +424 tripletas (sujetos 2977), offset 3600
#    [trip] +534 tripletas (sujetos 3059), offset 3750
#    [trip] +533 tripletas (sujetos 3137), offset 3900
#    [trip] +913 tripletas (sujetos 3274), offset 4050
#    [trip] +907 tripletas (sujetos 3418), offset 4200
#    [trip] +160 tripletas (sujetos 3440), offset 4350
#    [trip] +746 tripletas (sujetos 3558), offset 4500
#    [trip] +435 tripletas (sujetos 3621), offset 4650
#    [trip] +1077 tripletas (sujetos 3771), offset 4800
#    [trip] +1058 tripletas (sujetos 3921), offset 4950
#    [trip] +711 tripletas (sujetos 4030), offset 5100
#    [trip] +654 tripletas (sujetos 4129), offset 5250
#    [trip] +550 tripletas (sujetos 4221), offset 5400
#    [trip] +721 tripletas (sujetos 4343), offset 5550
#    [trip] +704 tripletas (sujetos 4455), offset 5700
#    [trip] +490 tripletas (sujetos 4536), offset 5850
#    [trip] +900 tripletas (sujetos 4683), offset 6000
#    [trip] +790 tripletas (sujetos 4833), offset 6150
#    [trip] +440 tripletas (sujetos 4906), offset 6300
#    [trip] +791 tripletas (sujetos 5039), offset 6450
#    [trip] +57 tripletas (sujetos 5050), offset 6600
#    [trip] +307 tripletas (sujetos 5105), offset 6750
#    [trip] +628 tripletas (sujetos 5221), offset 6900
#    [trip] +697 tripletas (sujetos 5370), offset 7050
#    [trip] +699 tripletas (sujetos 5511), offset 7200
#    [trip] +607 tripletas (sujetos 5629), offset 7350
#    [trip] +725 tripletas (sujetos 5774), offset 7500
#    [trip] +861 tripletas (sujetos 5924), offset 7650
#    [trip] +610 tripletas (sujetos 6031), offset 7800
#    [trip] +288 tripletas (sujetos 6093), offset 7950
#    [trip] +315 tripletas (sujetos 6153), offset 8100
#    [trip] +130 tripletas (sujetos 6179), offset 8250
#    [trip] +667 tripletas (sujetos 6304), offset 8400
#    [trip] +838 tripletas (sujetos 6454), offset 8550
#    [trip] +781 tripletas (sujetos 6601), offset 8700
#    [trip] +361 tripletas (sujetos 6674), offset 8850
#    [trip] +569 tripletas (sujetos 6796), offset 9000
#    [trip] +491 tripletas (sujetos 6882), offset 9150
#    [trip] +672 tripletas (sujetos 6979), offset 9300
#    [trip] +682 tripletas (sujetos 7098), offset 9450
#    [trip] +522 tripletas (sujetos 7198), offset 9600
#    [trip] +746 tripletas (sujetos 7338), offset 9750
#    [trip] +636 tripletas (sujetos 7462), offset 9900
#    [trip] +731 tripletas (sujetos 7612), offset 10050
#    [trip] +597 tripletas (sujetos 7739), offset 10200
#    [trip] +329 tripletas (sujetos 7809), offset 10350
#    [trip] +539 tripletas (sujetos 7909), offset 10500
#    [trip] +855 tripletas (sujetos 8051), offset 10650
#    [trip] +684 tripletas (sujetos 8173), offset 10800
#    [trip] +684 tripletas (sujetos 8292), offset 10950
#    [trip] +490 tripletas (sujetos 8369), offset 11100
#    [trip] +764 tripletas (sujetos 8499), offset 11250
#    [trip] +762 tripletas (sujetos 8649), offset 11400
#    [trip] +792 tripletas (sujetos 8791), offset 11550
#    [trip] +650 tripletas (sujetos 8927), offset 11700
#    [trip] +548 tripletas (sujetos 9057), offset 11850
#    [cut] per_country_max=12000
# ✔ USA listo. Tripletas nuevas: 60610

# %%
# Consolidar a nodes/edges
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}; edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}
    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True); tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt,
                      "property_pid": t["property_pid"], "property_label": t["property_label"]})
    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_filename: str, title: str, domain_tag: str):
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    out = os.path.join(CHECKPOINT_DIR, output_filename)
    with open(out,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {out} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

consolidate_triplets_to_graph_json("kg_pintores_us.json",
                                   title="Pintores/as con ciudadanía de Estados Unidos (Wikidata)",
                                   domain_tag="pintores_us")
# Out:
# Consolidando 60610 tripletas…
# ✅ Guardado: C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_pintores_us\kg_pintores_us.json (nodos 17014, aristas 60610)

# %% [markdown]
# ### Danza (FAIL!)

# %%
# --- DANZAS USA: streaming ultrarresistente ---
import os, json, time, random, socket, glob, re
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# Carpeta de checkpoints (usa una NUEVA para no mezclar)
CHECKPOINT_DIR = r"C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_danzas_us_roots"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

COUNTRY_QID = "Q30"          # United States of America

# Roots de danza: mantenemos pocos (puedes sumar luego). Mejor empezar con 1 y ampliar.
DANCE_ROOTS = [
    "Q17156315",  # dance
    "Q201022",    # folk dance
    "Q3209069",   # social dance
    "Q1061584",   # street dance
    "Q123704",    # swing (group of dances)
    "Q244475",    # tap dance (item concreto)
    "Q2071053",   # hip hop dance (item concreto)
]


# Modo de vínculo a país (corremos cada uno por separado)
LINK_MODES = ["P495", "P17", "P131P17"]  # origen; país; ubicación->país

# Parámetros de robustez (empieza chico, luego sube)
PAGE_SIZE           = 80     # más pequeño para bajar carga
TRIPLET_BATCH       = 120
PER_COMBO_MAX       = 2500   # tope por (root, link)
SLEEP_BETWEEN_PAGES = 0.7

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

def _sparql(query: str, throttle_s: float = 0.35, max_retries: int = 7,
            base_sleep: float = 1.2, timeout_s: int = 90):
    """SPARQL con timeout + backoff exponencial + jitter."""
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (research)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0, 0.8)
                print(f"[WARN] HTTP {e.code}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0, 0.8)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# ---- Checkpoint helpers por (root, link) ----
def _prefix(root_qid: str, link_mode: str): return f"{root_qid}_{link_mode}"
def _items_path(root_qid, link_mode):   return os.path.join(CHECKPOINT_DIR, f"items_{_prefix(root_qid,link_mode)}.jsonl")
def _triplets_path(root_qid, link_mode):return os.path.join(CHECKPOINT_DIR, f"triplets_{_prefix(root_qid,link_mode)}.jsonl")
def _offset_path(root_qid, link_mode):  return os.path.join(CHECKPOINT_DIR, f"offset_{_prefix(root_qid,link_mode)}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(root_qid, link_mode):
    p=_offset_path(root_qid, link_mode)
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(root_qid, link_mode, off):
    with open(_offset_path(root_qid, link_mode),"w") as f: f.write(str(off))
# Propiedades que queremos en tripletas
DANCE_PROP_WHITELIST = ["P31","P279","P361","P495","P17","P131","P136"]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or DANCE_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)
    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    out=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid = b["p"]["value"].split("/")[-1]; pid = pid.split(":")[-1] if ":" in pid else pid
        p_lab = b.get("propLabel",{}).get("value", pid)
        o_val = b["o"]["value"]; o_lab = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        out.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return out

def fetch_items_page_us(root_qid: str, link_mode: str, offset: int, limit: int) -> List[str]:
    """Página de ítems para un root y un modo de vínculo al país."""
    if link_mode == "P495":
        link = " ?item wdt:P495 ?country . "
    elif link_mode == "P17":
        link = " ?item wdt:P17 ?country . "
    elif link_mode == "P131P17":
        link = " ?item wdt:P131/wdt:P17 ?country . "
    else:
        raise ValueError("link_mode inválido")

    # Sólo un root y sólo un camino (P31/wdt:P279*). Evitamos UNION.
    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{COUNTRY_QID} }}
      # ?item wdt:P31/wdt:P279* wd:{root_qid} .
      {link}
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
def stream_us_dances_by_root(root_qid: str, link_mode: str,
                             per_combo_max: int=PER_COMBO_MAX,
                             page_size: int=PAGE_SIZE,
                             triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path(root_qid, link_mode)
    trips_file = _triplets_path(root_qid, link_mode)
    off  = _read_offset(root_qid, link_mode)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ USA dances | root={root_qid} | link={link_mode} | offset={off} | done={len(done)}")

    while True:
        ids = fetch_items_page_us(root_qid, link_mode, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        _append_jsonl(items_file, [{"qid": q} for q in ids])  # checkpoint de ítems

        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk, prop_whitelist=DANCE_PROP_WHITELIST)
                    if trip:
                        _append_jsonl(trips_file, trip)  # checkpoint de tripletas
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} ({len(done)} sujetos), offset {off}")
                except Exception as e:
                    print(f"   [WARN] lote tripletas offset {off}: {e} — continuo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(root_qid, link_mode, off)
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_combo_max:
            print(f"   [cut] per_combo_max={per_combo_max}"); break

    print(f"✔ root={root_qid} | link={link_mode} listo. Tripletas nuevas: {total_new}")

# %%
# Empieza MUY pequeño: 1 root y sólo P495.
for r in ["Q17156315"]:           # primero solo dance
    for link in ["P495"]:         # primero sólo país de origen
        stream_us_dances_by_root(r, link)

# Si ves resultados, añade P17:
for r in ["Q17156315"]:
    for link in ["P17"]:
        stream_us_dances_by_root(r, link)

# Luego añade la ruta P131→P17:
for r in ["Q17156315"]:
    for link in ["P131P17"]:
        stream_us_dances_by_root(r, link)

# Cuando ya confirmes que devuelve, añade más roots (folk/social) del listado DANCE_ROOTS:
for r in ["Q201022", "Q3209069"]:
    for link in ["P495","P17","P131P17"]:
        stream_us_dances_by_root(r, link)
# Out:
# → USA dances | root=Q17156315 | link=P495 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q17156315 | link=P495 listo. Tripletas nuevas: 0
# → USA dances | root=Q17156315 | link=P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q17156315 | link=P17 listo. Tripletas nuevas: 0
# → USA dances | root=Q17156315 | link=P131P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q17156315 | link=P131P17 listo. Tripletas nuevas: 0
# → USA dances | root=Q201022 | link=P495 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q201022 | link=P495 listo. Tripletas nuevas: 0
# → USA dances | root=Q201022 | link=P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q201022 | link=P17 listo. Tripletas nuevas: 0
# → USA dances | root=Q201022 | link=P131P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q201022 | link=P131P17 listo. Tripletas nuevas: 0
# → USA dances | root=Q3209069 | link=P495 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q3209069 | link=P495 listo. Tripletas nuevas: 0
# → USA dances | root=Q3209069 | link=P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q3209069 | link=P17 listo. Tripletas nuevas: 0
# → USA dances | root=Q3209069 | link=P131P17 | offset=0 | done=0
#    [fin] no hay más páginas.
# ✔ root=Q3209069 | link=P131P17 listo. Tripletas nuevas: 0

# %% [markdown]
# ### Peliculas

# %%
# --- CONFIG PELÍCULAS USA ---
import os, json, time, random, socket, glob, re
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

CHECKPOINT_DIR = r"C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_peliculas_us"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

COUNTRY_QID      = "Q30"        # United States of America
FILM_TYPE_QID    = "Q11424"     # film (toma subclases con P31/P279*)
PAGE_SIZE        = 120          # moderado para evitar 429/504
TRIPLET_BATCH    = 150
PER_MODE_MAX     = 12000        # tope por ruta de país
SLEEP_BETWEEN_PAGES = 0.5

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"
def _sparql(query: str, throttle_s: float = 0.3, max_retries: int = 7,
            base_sleep: float = 1.0, timeout_s: int = 90):
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (research)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0, 0.7)
                print(f"[WARN] HTTP {e.code}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0, 0.7)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# --- archivos por "modo de vínculo a país" ---
def _items_path(mode):   return os.path.join(CHECKPOINT_DIR, f"items_{mode}.jsonl")
def _triplets_path(mode):return os.path.join(CHECKPOINT_DIR, f"triplets_{mode}.jsonl")
def _offset_path(mode):  return os.path.join(CHECKPOINT_DIR, f"offset_{mode}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset(mode):
    p=_offset_path(mode)
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(mode,off):
    with open(_offset_path(mode),"w") as f: f.write(str(off))
# Propiedades útiles para películas
FILM_PROP_WHITELIST = [
    "P31",   # instancia de
    "P136",  # género
    "P57",   # director
    "P58",   # guionista
    "P161",  # reparto
    "P364",  # idioma original
    "P577",  # fecha de estreno
    "P272",  # productora
    "P915",  # lugar de rodaje
    "P344",  # fotografía
    "P86",   # música
    "P495",  # país de origen
]

def fetch_triplets_for_entities(item_qids: List[str], prop_whitelist: List[str]=None) -> List[dict]:
    if not item_qids: return []
    prop_whitelist = prop_whitelist or FILM_PROP_WHITELIST
    p_list = ", ".join(f"wdt:{p}" for p in prop_whitelist)
    values_items = " ".join(f"wd:{q}" for q in item_qids)
    q = f"""
    SELECT DISTINCT ?item ?itemLabel ?p ?propLabel ?o ?oLabel WHERE {{
      VALUES ?item {{ {values_items} }}
      # ?item ?p ?o .
      # ?prop wikibase:directClaim ?p .
      FILTER(?p IN ({p_list}))
      {_label_service()}
    }}
    """
    data = _sparql(q)
    out=[]
    for b in data["results"]["bindings"]:
        s_qid = b["item"]["value"].split("/")[-1]
        s_label = b.get("itemLabel",{}).get("value", s_qid)
        pid = b["p"]["value"].split("/")[-1]; pid = pid.split(":")[-1] if ":" in pid else pid
        p_lab = b.get("propLabel",{}).get("value", pid)
        o_val = b["o"]["value"]; o_lab = b.get("oLabel",{}).get("value", o_val)
        if o_val.startswith("http://www.wikidata.org/entity/Q"):
            o_id = o_val.split("/")[-1]; is_ent=True
        else:
            o_id = o_val; is_ent=False
        out.append({
            "subject_qid": s_qid, "subject_label": s_label,
            "property_pid": pid, "property_label": p_lab,
            "object_id": o_id, "object_label": o_lab, "object_is_entity": is_ent
        })
    return out

def fetch_items_page_us(mode: str, offset: int, limit: int) -> List[str]:
    """
    Modo de país (uno por vez):
      - "P495"        : ?item wdt:P495 ?country
      - "P272P17"     : ?item wdt:P272 ?company . ?company wdt:P17 ?country
      - "P915P17"     : ?item wdt:P915 ?place   . ?place   wdt:P17 ?country
      - "P272P159P17" : ?item wdt:P272 ?company . ?company wdt:P159 ?hq . ?hq wdt:P17 ?country
    """
    if mode == "P495":
        link = " ?item wdt:P495 ?country . "
    elif mode == "P272P17":
        link = " ?item wdt:P272 ?company . ?company wdt:P17 ?country . "
    elif mode == "P915P17":
        link = " ?item wdt:P915 ?place . ?place wdt:P17 ?country . "
    elif mode == "P272P159P17":
        link = " ?item wdt:P272 ?company . ?company wdt:P159 ?hq . ?hq wdt:P17 ?country . "
    else:
        raise ValueError("Modo desconocido")

    q = f"""
    SELECT DISTINCT ?item WHERE {{
      VALUES ?country {{ wd:{COUNTRY_QID} }}
      # ?item wdt:P31/wdt:P279* wd:{FILM_TYPE_QID} .
      {link}
    }}
    LIMIT {limit}
    OFFSET {offset}
    """
    data = _sparql(q)
    return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
def stream_us_films(mode: str,
                    per_mode_max: int=PER_MODE_MAX,
                    page_size: int=PAGE_SIZE,
                    triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path(mode)
    trips_file = _triplets_path(mode)
    off  = _read_offset(mode)
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ Films USA | modo={mode} | offset={off} | sujetos con tripletas={len(done)}")

    while True:
        ids = fetch_items_page_us(mode, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        _append_jsonl(items_file, [{"qid": q} for q in ids])  # checkpoint de ítems

        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk, prop_whitelist=FILM_PROP_WHITELIST)
                    if trip:
                        _append_jsonl(trips_file, trip)      # checkpoint de tripletas
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] lote tripletas offset {off}: {e} — continuo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(mode, off)
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_mode_max:
            print(f"   [cut] per_mode_max={per_mode_max}"); break

    print(f"✔ modo={mode} listo. Tripletas nuevas: {total_new}")

# %%
stream_us_films("P495")
# Out:
# → Films USA | modo=P495 | offset=0 | sujetos con tripletas=0
#    [trip] +1095 (sujetos 120), offset 0
#    [trip] +1352 (sujetos 234), offset 120
#    [trip] +605 (sujetos 302), offset 240
#    [trip] +924 (sujetos 422), offset 360
#    [trip] +629 (sujetos 542), offset 480
#    [trip] +1073 (sujetos 662), offset 600
#    [trip] +538 (sujetos 730), offset 720
#    [trip] +462 (sujetos 794), offset 840
#    [trip] +469 (sujetos 861), offset 960
#    [trip] +715 (sujetos 955), offset 1080
#    [trip] +816 (sujetos 1047), offset 1200
#    [trip] +581 (sujetos 1130), offset 1320
#    [trip] +818 (sujetos 1247), offset 1440
#    [trip] +273 (sujetos 1291), offset 1560
#    [trip] +686 (sujetos 1391), offset 1680
#    [trip] +790 (sujetos 1504), offset 1800
#    [trip] +595 (sujetos 1592), offset 1920
#    [trip] +561 (sujetos 1697), offset 2040
#    [trip] +111 (sujetos 1708), offset 2160
#    [trip] +650 (sujetos 1828), offset 2280
#    [trip] +501 (sujetos 1902), offset 2400
#    [trip] +735 (sujetos 1995), offset 2520
#    [trip] +939 (sujetos 2115), offset 2640
#    [trip] +339 (sujetos 2169), offset 2760
#    [trip] +619 (sujetos 2266), offset 2880
#    [trip] +639 (sujetos 2323), offset 3000
#    [trip] +446 (sujetos 2383), offset 3120
#    [trip] +305 (sujetos 2426), offset 3240
#    [trip] +302 (sujetos 2462), offset 3360
#    [trip] +423 (sujetos 2502), offset 3480
#    [trip] +1457 (sujetos 2622), offset 3600
#    [trip] +3365 (sujetos 2742), offset 3720
#    [trip] +1105 (sujetos 2853), offset 3840
#    [trip] +2024 (sujetos 2926), offset 3960
#    [trip] +3219 (sujetos 3025), offset 4080
#    [trip] +3078 (sujetos 3112), offset 4200
#    [trip] +2664 (sujetos 3182), offset 4320
#    [trip] +472 (sujetos 3236), offset 4440
#    [trip] +2380 (sujetos 3347), offset 4560
#    [trip] +3543 (sujetos 3467), offset 4680
#    [trip] +4189 (sujetos 3587), offset 4920
#    [trip] +542 (sujetos 3630), offset 5040
#    [trip] +2853 (sujetos 3726), offset 5160
#    [trip] +1834 (sujetos 3791), offset 5280
#    [trip] +1227 (sujetos 3835), offset 5400
#    [trip] +2518 (sujetos 3914), offset 5520
#    [trip] +2049 (sujetos 3979), offset 5640
#    [trip] +1284 (sujetos 4018), offset 5760
#    [trip] +761 (sujetos 4044), offset 5880
#    [trip] +2485 (sujetos 4127), offset 6000
#    [trip] +2191 (sujetos 4205), offset 6120
#    [trip] +2790 (sujetos 4289), offset 6240
#    [trip] +2926 (sujetos 4383), offset 6360
#    [trip] +3371 (sujetos 4491), offset 6480
#    [trip] +3327 (sujetos 4609), offset 6600
#    [trip] +3400 (sujetos 4729), offset 6720
#    [trip] +2234 (sujetos 4796), offset 6840
#    [trip] +2196 (sujetos 4873), offset 6960
#    [trip] +3153 (sujetos 4982), offset 7080
#    [trip] +2580 (sujetos 5074), offset 7200
#    [trip] +1183 (sujetos 5113), offset 7320
#    [trip] +2850 (sujetos 5208), offset 7440
#    [trip] +573 (sujetos 5229), offset 7560
#    [trip] +2958 (sujetos 5340), offset 7680
#    [trip] +3327 (sujetos 5460), offset 7800
#    [trip] +268 (sujetos 5470), offset 7920
#    [trip] +1580 (sujetos 5525), offset 8040
#    [trip] +3756 (sujetos 5643), offset 8160
#    [trip] +2266 (sujetos 5729), offset 8280
#    [trip] +3051 (sujetos 5835), offset 8400
#    [trip] +2117 (sujetos 5907), offset 8520
#    [trip] +3056 (sujetos 6016), offset 8640
#    [trip] +1404 (sujetos 6069), offset 8760
#    [trip] +1949 (sujetos 6140), offset 8880
#    [trip] +3229 (sujetos 6260), offset 9000
#    [trip] +3199 (sujetos 6380), offset 9120
#    [trip] +2686 (sujetos 6477), offset 9240
#    [trip] +1729 (sujetos 6542), offset 9360
#    [trip] +3596 (sujetos 6662), offset 9480
#    [trip] +1835 (sujetos 6725), offset 9600
#    [trip] +3526 (sujetos 6845), offset 9720
#    [trip] +1929 (sujetos 6911), offset 9840
#    [trip] +943 (sujetos 6945), offset 9960
#    [trip] +2190 (sujetos 7032), offset 10080
#    [trip] +2068 (sujetos 7120), offset 10200
#    [trip] +3543 (sujetos 7233), offset 10320
#    [trip] +3416 (sujetos 7349), offset 10440
#    [trip] +1860 (sujetos 7415), offset 10560
#    [trip] +933 (sujetos 7451), offset 10680
#    [trip] +1033 (sujetos 7489), offset 10800
#    [trip] +1859 (sujetos 7555), offset 10920
#    [trip] +1901 (sujetos 7629), offset 11040
#    [trip] +1717 (sujetos 7695), offset 11160
#    [trip] +2956 (sujetos 7804), offset 11280
#    [trip] +744 (sujetos 7830), offset 11400
#    [trip] +2965 (sujetos 7944), offset 11520
#    [trip] +3075 (sujetos 8062), offset 11640
#    [trip] +1350 (sujetos 8118), offset 11760
#    [trip] +1860 (sujetos 8188), offset 11880
#    [cut] per_mode_max=12000
# ✔ modo=P495 listo. Tripletas nuevas: 176688

# %%
def build_graph_dict(triplets: List[dict], metadata: Dict=None) -> dict:
    nodes = {}; edges = []
    def add_node(node_id: str, label: str, is_entity: bool):
        if node_id not in nodes:
            nodes[node_id] = {"id": node_id, "label": label, "type": "entity" if is_entity else "literal"}
    for t in triplets:
        s = t["subject_qid"]; sl = t["subject_label"]
        add_node(s, sl, True)
        if t["object_is_entity"]:
            o = t["object_id"]; ol = t["object_label"]; add_node(o, ol, True); tgt = o
        else:
            o = f"L:{t['object_id']}"; add_node(o, t["object_label"], False); tgt = o
        edges.append({"source": s, "target": tgt,
                      "property_pid": t["property_pid"], "property_label": t["property_label"]})
    return {"metadata": metadata or {}, "nodes": list(nodes.values()), "edges": edges}

def consolidate_triplets_to_graph_json(output_filename: str, title: str, domain_tag: str):
    all_trip=[]
    for f in glob.glob(os.path.join(CHECKPOINT_DIR, "triplets_*.jsonl")):
        with open(f,"r",encoding="utf-8") as fh:
            for ln in fh:
                ln=ln.strip()
                if not ln: continue
                try:
                    obj=json.loads(ln)
                    if isinstance(obj, dict) and "subject_qid" in obj:
                        all_trip.append(obj)
                except: pass
    print(f"Consolidando {len(all_trip)} tripletas…")
    kg = build_graph_dict(all_trip, metadata={"title": title, "domain": domain_tag})
    out = os.path.join(CHECKPOINT_DIR, output_filename)
    with open(out,"w",encoding="utf-8") as f:
        json.dump(kg,f,ensure_ascii=False,indent=2)
    print(f"✅ Guardado: {out} (nodos {len(kg['nodes'])}, aristas {len(kg['edges'])})")

consolidate_triplets_to_graph_json("kg_peliculas_us.json",
                                   title="Películas vinculadas a Estados Unidos (Wikidata)",
                                   domain_tag="peliculas_us")
# Out:
# Consolidando 176688 tripletas…
# ✅ Guardado: C:\Users\tomas\OneDrive\Escritorio\IA_GEN_proyecto\ckpt_peliculas_us\kg_peliculas_us.json (nodos 51278, aristas 176688)

# %% [markdown]
# ### Pueblos indígenas

# %%
# --- CONFIG INDÍGENAS USA (Optimizaciones de consultas y tiempos) ---
import os, json, time, random, socket, glob
from typing import List, Dict
from urllib.error import HTTPError, URLError
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

# Carpeta de checkpoints
CHECKPOINT_DIR = r"C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_indigenas_us"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# Parámetros básicos
COUNTRY_QID = "Q30"           # United States of America
ETHNIC_GROUP_QID = "Q41710"   # ethnic group (común para grupos étnicos)
PAGE_SIZE = 60                # más pequeño para reducir el riesgo de 504
TRIPLET_BATCH = 120
PER_QUERY_MAX = 3000         # límite de ítems a traer (más pequeño por consulta)
SLEEP_BETWEEN_PAGES = 1.5    # más descanso entre peticiones

WIKIDATA_ENDPOINT = "https://query.wikidata.org/sparql"
LANGS = "es,en"

def _sparql(query: str, throttle_s: float = 0.35, max_retries: int = 7,
            base_sleep: float = 1.5, timeout_s: int = 90) -> dict:
    last_err = None
    for attempt in range(max_retries):
        try:
            s = SPARQLWrapper(WIKIDATA_ENDPOINT)
            s.setQuery(query)
            s.setReturnFormat(SP_JSON)
            try: s.setTimeout(timeout_s * 1000)
            except Exception: s.setTimeout(timeout_s)
            s.addCustomHttpHeader("User-Agent", "Tomniko-KG/1.0 (research)")
            res = s.query().convert()
            if throttle_s > 0: time.sleep(throttle_s)
            return res
        except HTTPError as e:
            last_err = e
            if e.code in (429, 502, 503, 504):
                sleep = base_sleep*(2**attempt) + random.uniform(0, 0.8)
                print(f"[WARN] HTTP {e.code}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
                time.sleep(sleep); continue
            raise
        except (URLError, socket.timeout, socket.gaierror) as e:
            last_err = e
            sleep = base_sleep*(2**attempt) + random.uniform(0, 0.8)
            print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
            time.sleep(sleep); continue
    raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")

def _label_service():
    return f'SERVICE wikibase:label {{ bd:serviceParam wikibase:language "{LANGS}". }}'

# --- Paths de checkpoint ---
def _prefix(root_qid: str, link_mode: str): return f"{root_qid}_{link_mode}"
def _items_path():    return os.path.join(CHECKPOINT_DIR, f"items_{COUNTRY_QID}.jsonl")
def _triplets_path(): return os.path.join(CHECKPOINT_DIR, f"triplets_{COUNTRY_QID}.jsonl")
def _offset_path():   return os.path.join(CHECKPOINT_DIR, f"offset_{COUNTRY_QID}.txt")

def _append_jsonl(path, records):
    with open(path, "a", encoding="utf-8") as f:
        for r in records: f.write(json.dumps(r, ensure_ascii=False) + "\n")

def _read_done_subjects(path):
    done=set()
    if not os.path.exists(path): return done
    with open(path,"r",encoding="utf-8") as f:
        for ln in f:
            ln=ln.strip()
            if not ln: continue
            try:
                obj=json.loads(ln)
                if isinstance(obj, dict) and "subject_qid" in obj:
                    done.add(obj["subject_qid"])
            except: pass
    return done

def _read_offset():
    p=_offset_path()
    if not os.path.exists(p): return 0
    try: return int(open(p,"r").read().strip())
    except: return 0

def _write_offset(off: int):
    with open(_offset_path(),"w") as f: f.write(str(off))
def stream_indigenous_us(per_query_max: int=PER_QUERY_MAX,
                         page_size: int=PAGE_SIZE,
                         triplet_batch: int=TRIPLET_BATCH):
    items_file = _items_path()
    trips_file = _triplets_path()
    off = _read_offset()
    done = _read_done_subjects(trips_file)

    total_new = 0
    print(f"→ Pueblos indígenas USA (vía P2341) desde offset {off}, sujetos ya con tripletas: {len(done)}")

    while True:
        ids = fetch_items_page_by_country(COUNTRY_QID, offset=off, limit=page_size)
        if not ids:
            print("   [fin] no hay más páginas."); break

        _append_jsonl(items_file, [{"qid": q} for q in ids])  # trazabilidad

        pending = [q for q in ids if q not in done]
        if pending:
            for i in range(0, len(pending), triplet_batch):
                chunk = pending[i:i+triplet_batch]
                try:
                    trip = fetch_triplets_for_entities(chunk)
                    if trip:
                        _append_jsonl(trips_file, trip)    # ← checkpoint inmediato
                        done.update({t["subject_qid"] for t in trip})
                        total_new += len(trip)
                        print(f"   [trip] +{len(trip)} tripletas (sujetos {len(done)}), offset {off}")
                except Exception as e:
                    print(f"   [WARN] fallo batch en offset {off}: {e}; sigo…")
                    time.sleep(1.0)

        off += page_size
        _write_offset(off)                      # ← guardo offset
        if SLEEP_BETWEEN_PAGES: time.sleep(SLEEP_BETWEEN_PAGES)
        if off >= per_query_max:
            print(f"   [cut] per_query_max={per_query_max}"); break

    print(f"✔ USA pueblos indígenas listo. Tripletas nuevas: {total_new}")

# %%
# Empieza con el scraping por país (USA)
for cq in ["Q30"]:  # Solo USA
    stream_indigenous_us(
        per_query_max=PER_QUERY_MAX,
        page_size=PAGE_SIZE,
        triplet_batch=TRIPLET_BATCH
    )
# Out:
# → Pueblos indígenas USA (vía P2341) desde offset 0, sujetos ya con tripletas: 0
# [WARN] HTTP 504. Reintento en 2.3s (1/7)…
# [WARN] HTTP 504. Reintento en 3.6s (2/7)…
# [WARN] HTTP 429. Reintento en 6.0s (3/7)…
# [WARN] HTTP 504. Reintento en 12.7s (4/7)…
# [WARN] HTTP 504. Reintento en 24.3s (5/7)…
# [WARN] HTTP 504. Reintento en 48.4s (6/7)…
# [WARN] HTTP 504. Reintento en 96.3s (7/7)…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[60], line 3
#       1 # Empieza con el scraping por país (USA)
#       2 for cq in ["Q30"]:  # Solo USA
# ----> 3     stream_indigenous_us(
#       4         per_query_max=PER_QUERY_MAX,
#       5         page_size=PAGE_SIZE,
#       6         triplet_batch=TRIPLET_BATCH
#       7     )
#
# Cell In[59], line 97, in stream_indigenous_us(per_query_max, page_size, triplet_batch)
#      94 print(f"→ Pueblos indígenas USA (vía P2341) desde offset {off}, sujetos ya con tripletas: {len(done)}")
#      96 while True:
# ---> 97     ids = fetch_items_page_by_country(COUNTRY_QID, offset=off, limit=page_size)
#      98     if not ids:
#      99         print("   [fin] no hay más páginas."); break
#
# Cell In[57], line 151, in fetch_items_page_by_country(cq, offset, limit)
#     132 """
#     133 Pueblos indígenas (Q41710) con vínculos a EE. UU. (P2341, P17, P131→P17).
#     134 """
#     135 q = f"""
#     136 SELECT DISTINCT ?item WHERE {{
#     137   VALUES ?country {{ wd:{cq} }}
#    (...)    149 OFFSET {offset}
#     150 """
# --> 151 data = _sparql(q)
#     152 return [ b["item"]["value"].split("/")[-1] for b in data["results"]["bindings"] ]
#
# Cell In[59], line 48, in _sparql(query, throttle_s, max_retries, base_sleep, timeout_s)
#      46         print(f"[WARN] Red: {e}. Reintento en {sleep:.1f}s ({attempt+1}/{max_retries})…")
#      47         time.sleep(sleep); continue
# ---> 48 raise RuntimeError(f"SPARQL falló tras {max_retries} reintentos: {last_err}")
#
# RuntimeError: SPARQL falló tras 7 reintentos: HTTP Error 504: Gateway Timeout

# %% [markdown]
# # Extracción de .json -> .csv

# %% [markdown]
# ## Codigo

# %%
# %%writefile json_to_csv_wikidata_labels.py
# -*- coding: utf-8 -*-
"""
Convierte un KG en JSON (con nodes/edges) a un CSV de tripletas con:
- relacion (property_label en español)
- valor (label humano, preferencia ES y además todos los idiomas)
Requiere: pip install SPARQLWrapper pandas
Uso:
  python json_to_csv_wikidata_labels.py input.json output.csv
"""

import sys
import json
import time
from collections import defaultdict
from typing import Dict, List, Tuple, Iterable
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON as SP_JSON

ENDPOINT = "https://query.wikidata.org/sparql"

def sparql(query: str, throttle_s: float = 0.2) -> dict:
    s = SPARQLWrapper(ENDPOINT)
    s.setQuery(query)
    s.setReturnFormat(SP_JSON)
    res = s.query().convert()
    if throttle_s > 0:
        time.sleep(throttle_s)
    return res

def chunked(iterable, n):
    buf = []
    for x in iterable:
        buf.append(x)
        if len(buf) >= n:
            yield buf
            buf = []
    if buf:
        yield buf

def fetch_all_lang_labels_for_Q(qids, batch_size=200):
    out = defaultdict(dict)
    for group in chunked(qids, batch_size):
        values = " ".join(f"wd:{q}" for q in group)
        query = f"""
        SELECT ?item ?label (LANG(?label) AS ?lang) WHERE {{
          VALUES ?item {{ {values} }}
          ?item rdfs:label ?label .
          FILTER(LANG(?label) != "")
        }}
        """
        data = sparql(query)
        for b in data["results"]["bindings"]:
            qid = b["item"]["value"].split("/")[-1]
            lab = b["label"]["value"]
            lang = b["lang"]["value"]
            out[qid][lang] = lab
    return dict(out)

def fetch_spanish_labels_for_P(pids, batch_size=300):
    out_es = {}
    missing = set(pids)

    for group in chunked(list(missing), batch_size):
        values = " ".join(f"wd:{p}" for p in group)
        q = f"""
        SELECT ?p ?label WHERE {{
          VALUES ?p {{ {values} }}
          ?p rdfs:label ?label .
          FILTER(LANG(?label) = "es")
        }}
        """
        data = sparql(q)
        for b in data["results"]["bindings"]:
            pid = b["p"]["value"].split("/")[-1]
            out_es[pid] = b["label"]["value"]
            if pid in missing:
                missing.remove(pid)

    if missing:
        for group in chunked(list(missing), batch_size):
            values = " ".join(f"wd:{p}" for p in group)
            q = f"""
            SELECT ?p ?label WHERE {{
              VALUES ?p {{ {values} }}
              ?p rdfs:label ?label .
              FILTER(LANG(?label) = "en")
            }}
            """
            data = sparql(q)
            for b in data["results"]["bindings"]:
                pid = b["p"]["value"].split("/")[-1]
                out_es[pid] = b["label"]["value"]
                if pid in missing:
                    missing.remove(pid)

    for pid in missing:
        out_es[pid] = pid

    return out_es

def json_to_triplets_csv(input_json, output_csv):
    with open(input_json, "r", encoding="utf-8") as f:
        data = json.load(f)

    nodes = data.get("nodes", [])
    edges = data.get("edges", [])

    id2label = {n["id"]: n.get("label", n["id"]) for n in nodes}
    qids_targets, qids_subjects, pids_props = set(), set(), set()

    for e in edges:
        src, tgt, pid = e.get("source", ""), e.get("target", ""), e.get("property_pid", "")
        if src.startswith("Q"):
            qids_subjects.add(src)
        if tgt.startswith("Q"):
            qids_targets.add(tgt)
        if pid.startswith("P"):
            pids_props.add(pid)

    labels_Q_targets = fetch_all_lang_labels_for_Q(sorted(qids_targets)) if qids_targets else {}
    labels_Q_subjects = fetch_all_lang_labels_for_Q(sorted(qids_subjects)) if qids_subjects else {}
    labels_P_es = fetch_spanish_labels_for_P(sorted(pids_props)) if pids_props else {}

    def prefer_es(labels):
        if not labels:
            return ""
        return labels.get("es") or labels.get("en") or next(iter(labels.values()))

    rows = []
    for e in edges:
        src, tgt, pid = e.get("source", ""), e.get("target", ""), e.get("property_pid", "")
        relacion = labels_P_es.get(pid, e.get("property_label", pid))
        sujeto_qid = src
        sujeto_es = prefer_es(labels_Q_subjects.get(sujeto_qid, {})) or id2label.get(src, sujeto_qid)
        if tgt.startswith("Q"):
            valor_qid = tgt
            valor_labels = labels_Q_targets.get(valor_qid, {})
            valor_es = prefer_es(valor_labels)
            valor = valor_es or id2label.get(tgt, valor_qid)
        elif tgt.startswith("L:"):
            valor_qid = ""
            valor = tgt[2:]
            valor_es = valor
        else:
            valor_qid = tgt
            valor = id2label.get(tgt, tgt)
            valor_es = valor
        rows.append({
            "sujeto_qid": sujeto_qid,
            "entidad": sujeto_es,
            "relacion": relacion,
            "valor": valor,
            "valor_es": valor_es,
            "valor_qid": valor_qid
        })

    df = pd.DataFrame(rows)
    df.to_csv(output_csv, index=False, encoding="utf-8")
    print(f"✅ CSV generado: {output_csv} ({len(df)} filas)")
    return df
# Out:
# Writing json_to_csv_wikidata_labels.py

# %% [markdown]
# ## Pintores LATAM

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("kg_pintores_latam.json", "pintores_latam.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: pintores_latam.csv (4670 filas)
#   sujeto_qid                      entidad             relacion  \
# 0    Q186630               Ernesto Sabato  lugar de nacimiento
# 1    Q369214  Vladímir Kibálchich Rusakov  lugar de nacimiento
# 2    Q332420    Rodrigo Arenas Betancourt  lugar de nacimiento
# 3    Q351618             Francisco Zúñiga  lugar de nacimiento
# 4    Q368350           Luis Arenal Bastar  lugar de nacimiento
#
#              valor         valor_es valor_qid
# 0            Rojas            Rojas  Q2280901
# 1  San Petersburgo  San Petersburgo      Q656
# 2         Fredonia         Fredonia  Q1442002
# 3         San José         San José     Q3070
# 4            Teapa            Teapa  Q4407951

# %% [markdown]
# ## Landmarks LATAM

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_sitios/kg_sitios_interes_latam.json", "landmarks_latam.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: pintores_latam.csv (103493 filas)
#    sujeto_qid                           entidad      relacion  \
# 0    Q1765390  Parque nacional de Pacaás Nuevos  instancia de
# 1   Q48878268         Centro e Centro Histórico  instancia de
# 2   Q10301156                   Ilha da Pombeba  instancia de
# 3  Q123473720    Sub Prefeitura de Serra Pelada  instancia de
# 4     Q332381           Parque nacional del Jaú  instancia de
#
#              valor         valor_es valor_qid
# 0  parque nacional  parque nacional    Q46169
# 1    Subprefectura    Subprefectura  Q1367821
# 2  isla artificial  isla artificial    Q13691
# 3    Subprefectura    Subprefectura  Q1367821
# 4  parque nacional  parque nacional    Q46169

# %% [markdown]
# ## Peliculas LATAM

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_peliculas/kg_peliculas_latam.json", "cine_latam.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: cine_latam.csv (151363 filas)
#   sujeto_qid                       entidad  \
# 0     Q77151             Última Parada 174
# 1     Q72162          Infancia clandestina
# 2    Q135401  Xingu: la misión al Amazonas
# 3     Q72162          Infancia clandestina
# 4     Q84022                    Bossa Nova
#
#                                          relacion           valor  \
# 0  idioma de la película o programa de televisión       portugués
# 1                                        director  Benjamín Ávila
# 2                             miembro del reparto       Caio Blat
# 3                                        duración             110
# 4  idioma de la película o programa de televisión         español
#
#          valor_es  valor_qid
# 0       portugués      Q5146
# 1  Benjamín Ávila  Q13612488
# 2       Caio Blat   Q2628993
# 3             110
# 4         español      Q1321

# %% [markdown]
# ## Danzas LATAM

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_danzas_por_pais/kg_danzas_por_pais.json", "danzas_por_pais_latam.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: danzas_por_pais_latam.csv (1401 filas)
#   sujeto_qid                   entidad        relacion           valor  \
# 0   Q1046768  música popular brasileña  país de origen          Brasil
# 1   Q1455932                     Frevo    instancia de  género musical
# 2    Q505343                     Jongo    instancia de  género musical
# 3    Q834959                Samba rock     subclase de           samba
# 4    Q430075                    Maxixe    instancia de  género musical
#
#          valor_es valor_qid
# 0          Brasil      Q155
# 1  género musical   Q188451
# 2  género musical   Q188451
# 3           samba    Q11403
# 4  género musical   Q188451

# %% [markdown]
# ## Grupos étnicos LATAM

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_indigenas/kg_pueblos_indigenas_latam.json", "pueblos_indigenas_latam.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: pueblos_indigenas_latam.csv (4079 filas)
#   sujeto_qid                               entidad  \
# 0    Q572484                             yaminahua
# 1   Q3891599  Los indígenas de Raposa Serra do Sol
# 2   Q2537324                            Yawalapiti
# 3   Q3891599  Los indígenas de Raposa Serra do Sol
# 4   Q3891599  Los indígenas de Raposa Serra do Sol
#
#                      relacion             valor          valor_es   valor_qid
# 0  nombre en la lengua nativa          Yaminawá          Yaminawá
# 1              idioma oficial    Idioma macushi    Idioma macushi      Q56633
# 2              país de origen            Brasil            Brasil        Q155
# 3              idioma oficial  Língua Taulipáng  Língua Taulipáng  Q114277006
# 4              idioma oficial  Língua Wapichana  Língua Wapichana  Q114277007

# %% [markdown]
# ## CSV EEUU

# %% [markdown]
# ### Pintores

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_pintores_us/kg_pintores_us.json", "pintores_us.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: pintores_us.csv (60610 filas)
#   sujeto_qid              entidad              relacion           valor  \
# 0      Q5912       Marcel Duchamp  país de nacionalidad         Francia
# 1     Q45132      Rudy Youngblood  país de nacionalidad          México
# 2     Q27507         Frank Malina  país de nacionalidad  Estados Unidos
# 3    Q164358  Robert Rauschenberg  país de nacionalidad  Estados Unidos
# 4    Q164358  Robert Rauschenberg  país de nacionalidad        Alemania
#
#          valor_es valor_qid
# 0         Francia      Q142
# 1          México       Q96
# 2  Estados Unidos       Q30
# 3  Estados Unidos       Q30
# 4        Alemania      Q183

# %% [markdown]
# ### Peliculas

# %%
from json_to_csv_wikidata_labels import json_to_triplets_csv

# Convertir el JSON a CSV
df = json_to_triplets_csv("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/ckpt_peliculas_us/kg_peliculas_us.json", "peliculas_us.csv")

# Mostrar las primeras filas
df.head()
# Out:
# ✅ CSV generado: peliculas_us.csv (176688 filas)
#   sujeto_qid          entidad      relacion                            valor  \
# 0   Q7194337            Pilot  instancia de  episodio de serie de televisión
# 1   Q7945086      W*A*L*T*E*R  instancia de                  episodio piloto
# 2   Q7194379            Pilot  instancia de                  episodio piloto
# 3   Q7711132  That '70s Pilot  instancia de                  episodio piloto
# 4   Q7194346            Pilot  instancia de  episodio de serie de televisión
#
#                           valor_es  valor_qid
# 0  episodio de serie de televisión  Q21191270
# 1                  episodio piloto    Q653916
# 2                  episodio piloto    Q653916
# 3                  episodio piloto    Q653916
# 4  episodio de serie de televisión  Q21191270

# %% [markdown]
# # Testeo json

# %%
import json, re

REPL_BASE = {
    "Â¿": "¿", "Â¡": "¡", "Â«": "«", "Â»": "»", "Â ": " ", "Â": ""
}

MAP_MOJI = {
    "Ã¡":"á","Ãé":"é","Ãí":"í","Ãó":"ó","Ãú":"ú",
    "ÃÁ":"Á","ÃÉ":"É","ÃÍ":"Í","ÃÓ":"Ó","ÃÚ":"Ú",
    "Ã±":"ñ","Ã‘":"Ñ","Ã¼":"ü","Ãœ":"Ü","Ã§":"ç","ÃÇ":"Ç",
    "Ã“":"Ó","Ãº":"ú","Ã³":"ó","Ã¨":"è","Ãª":"ê","Ã©":"é",
    "Ã¨":"è","Ã´":"ô","Ã¶":"ö","Ã¤":"ä","Ã¢":"â","Ã­":"í",  # última línea de seguridad
}

_moji_pat = re.compile(r"(Ã.|Â|â..|�)")
def tiene_mojibake(s): return isinstance(s, str) and bool(_moji_pat.search(s))

def arreglar_mojibake_hibrido(s: str) -> str:
    if not isinstance(s, str):
        return s
    t = s
    # 1) reemplazos base
    for a,b in REPL_BASE.items():
        t = t.replace(a,b)
    # 2) intento latin1->utf8 (puede fallar por ¿/¡ restantes)
    try:
        t2 = t.encode("latin-1").decode("utf-8")
        if _moji_pat.findall(t2).__len__() < _moji_pat.findall(t).__len__():
            t = t2
    except UnicodeDecodeError:
        pass
    # 3) mapa de pares comunes
    for a,b in MAP_MOJI.items():
        t = t.replace(a,b)
    return t

with open("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/TESTEO_JSON/usa_qa.json","r",encoding="utf-8") as f:
    data = json.load(f)

data_limpio = []
for it in data:
    it = dict(it)
    for k in ("pregunta","respuesta_correcta"):
        it[k] = arreglar_mojibake_hibrido(it.get(k,""))
    data_limpio.append(it)

with open("USA_qa_limpio.json","w",encoding="utf-8") as f:
    json.dump(data_limpio, f, ensure_ascii=False, indent=2)

# %%
import json

with open("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/TESTEO_JSON/USA_qa_limpio.json", 'r', encoding='utf-8') as f:
    data = json.load(f)

def tiene_mojibake(s: str) -> bool:
    return isinstance(s, str) and any(tok in s for tok in ("Ã±", "Ã¡", "Ã©", "Â", "â", "Ã"))

muestras = [(d.get('pregunta',''), d.get('respuesta_correcta','')) for d in data[:20]]
print([ (tiene_mojibake(p), tiene_mojibake(r)) for p,r in muestras ])
# Out:
# [(False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False), (False, False)]

# %%
import json, re

REPL_BASE = {
    "Â¿": "¿", "Â¡": "¡", "Â«": "«", "Â»": "»", "Â ": " ", "Â": ""
}

MAP_MOJI = {
    "Ã¡":"á","Ãé":"é","Ãí":"í","Ãó":"ó","Ãú":"ú",
    "ÃÁ":"Á","ÃÉ":"É","ÃÍ":"Í","ÃÓ":"Ó","ÃÚ":"Ú",
    "Ã±":"ñ","Ã‘":"Ñ","Ã¼":"ü","Ãœ":"Ü","Ã§":"ç","ÃÇ":"Ç",
    "Ã“":"Ó","Ãº":"ú","Ã³":"ó","Ã¨":"è","Ãª":"ê","Ã©":"é",
    "Ã¨":"è","Ã´":"ô","Ã¶":"ö","Ã¤":"ä","Ã¢":"â","Ã­":"í", "Ã": "Ú"  # última línea de seguridad
}

_moji_pat = re.compile(r"(Ã.|Â|â..|�)")
def tiene_mojibake(s): return isinstance(s, str) and bool(_moji_pat.search(s))

def arreglar_mojibake_hibrido(s: str) -> str:
    if not isinstance(s, str):
        return s
    t = s
    # 1) reemplazos base
    for a,b in REPL_BASE.items():
        t = t.replace(a,b)
    # 2) intento latin1->utf8 (puede fallar por ¿/¡ restantes)
    try:
        t2 = t.encode("latin-1").decode("utf-8")
        if _moji_pat.findall(t2).__len__() < _moji_pat.findall(t).__len__():
            t = t2
    except UnicodeDecodeError:
        pass
    # 3) mapa de pares comunes
    for a,b in MAP_MOJI.items():
        t = t.replace(a,b)
    return t

with open("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/TESTEO_JSON/justo_qa.json","r",encoding="utf-8") as f:
    data = json.load(f)

data_limpio = []
for it in data:
    it = dict(it)
    for k in ("pregunta","respuesta_correcta"):
        it[k] = arreglar_mojibake_hibrido(it.get(k,""))
    data_limpio.append(it)

with open("justo_qa_limpio.json","w",encoding="utf-8") as f:
    json.dump(data_limpio, f, ensure_ascii=False, indent=2)

# %%
import json

with open("C:/Users/tomas/OneDrive/Escritorio/IA_GEN_proyecto/TESTEO_JSON/USA_qa_limpio.json", 'r', encoding='utf-8') as f:
    data = json.load(f)

def tiene_mojibake(s: str) -> bool:
    return isinstance(s, str) and any(tok in s for tok in ("Ã±", "Ã¡", "Ã©", "Â", "â", "Ã"))

muestras = [(d.get('pregunta',''), d.get('respuesta_correcta','')) for d in data[:20]]
print([ (tiene_mojibake(p), tiene_mojibake(r)) for p,r in muestras ])
